# %%
import pandas as pd
import pickle
from scipy.sparse import hstack
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
import eli5
import numpy as np
from sklearn.model_selection import GridSearchCV, StratifiedKFold, cross_val_score,TimeSeriesSplit
import warnings
from IPython.display import display_html
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
import matplotlib.pyplot as plt

# %%
def site_sparse_matrix(path_to_train, path_to_test, pickle_file, vector_params):
    
    # all site columns
    sites = ['site%d' %i for i in range(1,11)]
    times = ['time%d' %i for i in range(1,11)]
    
    train_df = pd.read_csv(path_to_train, index_col='session_id', parse_dates=times)
    test_df = pd.read_csv(path_to_test, index_col='session_id', parse_dates=times)
    
    train_df = train_df.sort_values(by='time1')
    # clean data 
    train_df[sites] = train_df[sites].fillna(0).astype('int')
    test_df[sites] = test_df[sites].fillna(0).astype('int')

    
    with open(pickle_file,'rb') as input_file:
        site_id_dict = pickle.load(input_file)
    
    site_map={}
    for _name in site_id_dict:
        site_map[site_id_dict[_name]] = _name
    
    site_map[0]='unknown'

    #convert site id -> site name
    # it will help us to analysis after EDA
    # pd.dataframe .apply (axis=1) mean process each row
    train_session = train_df[sites].apply(lambda row: ' '.join([site_map[i] for i in row]), axis=1).tolist()
    test_session = test_df[sites].apply(lambda row: ' '.join([site_map[i] for i in row]), axis=1).tolist()
    
    # have word list now process bag of word 
    vectorizer = TfidfVectorizer(**vector_params)
    X_train = vectorizer.fit_transform(train_session)
    X_test = vectorizer.transform(test_session)
    y_train = train_df['target'].astype('int').values
    train_times = train_df[times]
    test_times = test_df[times]
    
    
    return X_train, X_test, y_train, vectorizer, train_times, test_times

# Function for writing predictions to a file
def write_to_submission_file(predicted_labels, out_file,
                             target='target', index_label="session_id"):
    predicted_df = pd.DataFrame(predicted_labels,
                                index = np.arange(1, predicted_labels.shape[0] + 1),
                                columns=[target])
    predicted_df.to_csv(out_file, index_label=index_label)

# %%
# prepare site sparse matrix
train_session, test_session, y_train, tfv, train_times, test_times = site_sparse_matrix('train_sessions.csv','test_sessions.csv','site_dic.pkl',
                                                                                       vector_params={'ngram_range':(1,5),'max_features':50000,'tokenizer':lambda s: s.split(" ")})

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold, cross_val_score,TimeSeriesSplit

logit = LogisticRegression(C=1.0, random_state=17, solver='liblinear', max_iter=100, n_jobs=-1)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)
time_split = TimeSeriesSplit(n_splits=10)
cv_scores1 = cross_val_score(logit, train_session, y_train, cv=skf, 
                            scoring='roc_auc', n_jobs=4)
print(cv_scores1)
logit.fit(train_session, y_train)
eli5.show_weights(estimator=logit, feature_names=tfv.get_feature_names(), top=30)
# Out:
# [0.95536723 0.950069   0.95015396 0.95351103 0.95363514]
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.880
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.380
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.222
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.86%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.114
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.875
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.499
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.220
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.147
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.089
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.72%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.003
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.74%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.993
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.945
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r4---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.95%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.917
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         reviewer.lavoixdunord.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.01%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.893
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.783
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r3---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.711
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.686
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.596
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         i1.ytimg.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.593
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.536
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.video.tt
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.521
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.purepeople.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.06%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.512
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %%
# Time feature EDA
import seaborn as sns
from scipy.sparse import hstack

session_start_time = train_times['time1'].apply(lambda ts: ts.hour).values

# %%
sns.countplot(session_start_time)

# %%
other_start_time = session_start_time[y_train==0]
alice_start_time = session_start_time[y_train==1]
_, ax = plt.subplots(1,2, figsize=(12,6))
sns.countplot(other_start_time,ax=ax[0]).set_title('other')
sns.countplot(alice_start_time,ax=ax[1]).set_title('Alice')
# other people mainly start at morning 
# Alice mainly focus on lunch time and 16-18
# Out:
# Text(0.5, 1.0, 'Alice')

# %%
# make four categories
morning = ((session_start_time>=7)&(session_start_time<=11)).astype('int')
day = ((session_start_time>=12)&(session_start_time<=18)).astype('int')
evening = ((session_start_time>=19)&(session_start_time<=23)).astype('int')
night = ((session_start_time>=0)&(session_start_time<=6)).astype('int')

scaling_start_hour = session_start_time/24

# %%
pd.crosstab([morning, day, evening, night], y_train, rownames=['morning', 'day', 'evening', 'night'])
# Out:
# col_0                           0     1
# morning day evening night
# 0       0   1       0        7251     0
#         1   0       0      122129  2256
# 1       0   0       0      121884    41

# %%
def add_start_time_feature(X_train, X_train_time, add_hour=True):
    session_start_time = X_train_time['time1'].apply(lambda ts: ts.hour)
    morning = ((session_start_time>=7)&(session_start_time<=11)).astype('int').values.reshape(-1,1)
    day = ((session_start_time>=12)&(session_start_time<=18)).astype('int').values.reshape(-1,1)
    evening = ((session_start_time>=19)&(session_start_time<=23)).astype('int').values.reshape(-1,1)
    night = ((session_start_time>=0)&(session_start_time<=6)).astype('int').values.reshape(-1,1)
    # np.hstack make should each array should have same dim
    # practice how to merge certain array together
    all_features = [X_train, morning, day, evening, night]
    time_features = ['morning','day','evening','night']
    if add_hour:
        scaling_start_hour = session_start_time/24
        scaling_start_hour = scaling_start_hour.values.reshape(-1,1)
        all_features.append(scaling_start_hour) # don't use a = [a,b] it will make a sublist 
        time_features.append('start_hour_rescale')
    
    all_features = hstack(all_features)
    return all_features, time_features

# %%
# train new model after adding start time feature
new_train_feat_whour, new_features1= add_start_time_feature(train_session, train_times)
new_test_feat_whour, _ = add_start_time_feature(test_session, test_times)
new_train_feat_nohour, new_features2 = add_start_time_feature(train_session, train_times, False)
new_test_feat_nohour, _ = add_start_time_feature(test_session, test_times, False)

# %%
def train_and_predict(model, X_train, y_train, X_test, site_features=tfv.get_feature_names(), new_feature_names=None,
                     cv=time_split, scoring='roc_auc', top_n_features=30, submission_file='submission.csv'):
    
    cv_score = cross_val_score(model, X_train, y_train, cv=time_split, scoring=scoring, n_jobs=-1)
    print('CV ROC Score->{} \r mean: {}, std: {}'.format(cv_score,np.mean(cv_score), np.std(cv_score)))
    model.fit(X_train, y_train)
    
    if new_feature_names:
        all_feature_names = site_features + new_feature_names
    else:
        all_feature_names = site_features
    
    display_html(eli5.show_weights(estimator=model, feature_names=all_feature_names, top=top_n_features))
    
    test_pred = model.predict_proba(X_test)[:,-1]
    write_to_submission_file(test_pred, out_file=submission_file)
    
    return cv_score

# %%
# with hour value
logit_new = LogisticRegression(C=1.0, random_state=17, n_jobs=-1, solver='liblinear', max_iter=100)
cv_add_start_time_feat1 = train_and_predict(logit_new, new_train_feat_whour, y_train, new_test_feat_whour, site_features=tfv.get_feature_names(), new_feature_names=new_features1,
                     cv=time_split, scoring='roc_auc', top_n_features=30, submission_file='submission2.csv')
# Out:
# CV ROC Score->[0.81904687 0.78705941 0.94510729 0.96676436 0.88993687 0.96695898
#  mean: 0.9167576893172427, std: 0.06210632157468878
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.046
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         start_hour_rescale
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.02%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.148
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.986
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.63%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.833
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.804
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.679
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.567
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.62%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.330
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.08%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.100
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.962
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.78%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.759
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.674
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r4---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.08%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.617
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.566
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.558
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.494
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         i1.ytimg.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.464
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.tete-en-lair.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.48%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.429
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.purepeople.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.420
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.clermont-filmfest.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.352
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.71%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.325
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.demotivateur.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.307
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         br

# %%
pd.DataFrame({'new_feat': new_features1, 'coef': logit_new.coef_[0][-len(new_features1):]})
# Out:
#              new_feat      coef
# 0             morning -2.904833
# 1                 day -0.613841
# 2             evening -5.069779
# 3               night  0.000000
# 4  start_hour_rescale  7.045650

# %%
# without hour value
logit_new = LogisticRegression(C=1.0, random_state=17, n_jobs=-1, solver='liblinear', max_iter=100)
cv_add_start_time_feat2 = train_and_predict(logit_new, new_train_feat_nohour, y_train, new_test_feat_nohour, site_features=tfv.get_feature_names(), new_feature_names=new_features2,
                     cv=time_split, scoring='roc_auc', top_n_features=30, submission_file='submission3.csv')
# Out:
# CV ROC Score->[0.88170019 0.81426901 0.91861247 0.96171465 0.91532998 0.95227476
#  mean: 0.9211539394820711, std: 0.04206422641352535
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.218
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.093
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.971
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.29%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.914
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.640
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.30%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.542
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.74%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.382
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.29%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.183
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.104
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.823
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r4---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.77%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.663
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.615
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.97%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.594
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.589
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.04%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.570
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         i1.ytimg.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.08%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.559
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.11%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.546
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.527
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         reviewer.lavoixdunord.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.30%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.484
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.39%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.453
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.384
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r3---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.354
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %%
pd.DataFrame({'new_feat': new_features2, 'coef': logit_new.coef_[0][-len(new_features2):]})
# Out:
#   new_feat      coef
# 0  morning -3.211819
# 1      day  0.526636
# 2  evening -2.721465
# 3    night  0.000000

# %%
# add duration time into feature
durTime_train = (train_times.max(axis=1)-train_times.min(axis=1)).astype('timedelta64[s]').astype(int).values.reshape(-1,1)
durTime_test = (test_times.max(axis=1)-test_times.min(axis=1)).astype('timedelta64[s]').astype(int).values.reshape(-1,1)

scaler = StandardScaler()
durTime_train = scaler.fit_transform(durTime_train)
durTime_test = scaler.transform(durTime_test)

new_train_wdur = hstack([new_train_feat_nohour, durTime_train])
new_test_wdur = hstack([new_test_feat_nohour, durTime_test])

if 'duration time' not in new_features2:
    new_features2.append('duration time')
# Out:
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
logit_new = LogisticRegression(C=1.0, random_state=17, n_jobs=-1, solver='liblinear', max_iter=100)
cv_add_start_time_feat3 = train_and_predict(logit_new, new_train_wdur, y_train, new_test_wdur, site_features=tfv.get_feature_names(), new_feature_names=new_features2,
                     cv=time_split, scoring='roc_auc', top_n_features=30, submission_file='submission4.csv')
# Out:
# CV ROC Score->[0.86809822 0.81821851 0.91950263 0.96171682 0.91593618 0.95368736
#  mean: 0.9210072395169003, std: 0.04287807604836511
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.212
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.058
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.974
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.969
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.617
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.532
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.363
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.47%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.148
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.47%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.146
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.47%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.792
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r4---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.694
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.632
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.586
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.12%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.569
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.546
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.543
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         i1.ytimg.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.27%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.516
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.498
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         reviewer.lavoixdunord.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.496
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.434
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.76%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.350
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r3---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.331
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %% [markdown]
# ## Add YMD as numerical features into model
# ### 95.35%

# %%
## add Y/M/D 
scaler = StandardScaler()
train_weekday_feat = train_times['time1'].apply(lambda ts: ts.weekday()).values.reshape(-1,1)
train_yearmonth_feat = (train_times['time1'].apply(lambda ts: ts.year*100+ts.month)/1e5).values.reshape(-1,1)
train_month_feat = train_times['time1'].apply(lambda ts: ts.month).values.reshape(-1,1)


test_weekday_feat = test_times['time1'].apply(lambda ts: ts.weekday()).values.reshape(-1,1)
test_yearmonth_feat = (test_times['time1'].apply(lambda ts: ts.year*100+ts.month)/1e5).values.reshape(-1,1)
test_month_feat = test_times['time1'].apply(lambda ts: ts.month).values.reshape(-1,1)

# %%
# train_weekday_feat = scaler.fit_transform(train_weekday_feat)
train_yearmonth_feat = scaler.fit_transform(train_yearmonth_feat)
# train_month_feat = scaler.fit_transform(train_month_feat)

# test_weekday_feat = scaler.transform(test_weekday_feat)
test_yearmonth_feat = scaler.transform(test_yearmonth_feat)
# test_month_feat = scaler.transform(test_month_feat)

new_train_addYMD = hstack([new_train_wdur, train_weekday_feat, train_yearmonth_feat, train_month_feat])
new_test_addYMD = hstack([new_test_wdur, test_weekday_feat, test_yearmonth_feat, test_month_feat])

# %%
new_features2 = new_features2[:5]
new_features2+=['weekday', 'yearmonth','month']

# %%
logit_new = LogisticRegression(C=4.6415, penalty='l2' ,random_state=17, n_jobs=-1, solver='liblinear', max_iter=100)
cv_add_YMD_feat = train_and_predict(logit_new, new_train_addYMD, y_train, new_test_addYMD, site_features=tfv.get_feature_names(), new_feature_names=new_features2,
                     cv=time_split, scoring='roc_auc', top_n_features=30, submission_file='submission.csv')
# Out:
# CV ROC Score->[0.78764245 0.79651133 0.94990119 0.97234163 0.9196626  0.95721145
#  mean: 0.9203884143314849, std: 0.06563361972305161
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +11.615
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +11.270
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.832
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         tru.am
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.170
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.72%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.472
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.294
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.01%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.271
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.116
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.962
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mcetv.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.812
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.springboardplatform.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.78%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.743
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.712
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.687
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.659
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.613
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.video.tt
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.02%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.583
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.568
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.radio-canada.ca
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.533
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.clermont-filmfest.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.503
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.464
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.rhonealpesjob.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.383
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.tete-en-lair.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.37%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.353
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>

# %%
pd.DataFrame({'feat_name': new_features2, 'coef': logit_new.coef_[0][-len(new_features2):]})
# Out:
#        feat_name      coef
# 0        morning -3.164513
# 1            day  0.765722
# 2        evening -3.692111
# 3          night  0.000000
# 4  duration time -0.202630
# 5        weekday -0.397970
# 6      yearmonth -0.410162
# 7          month  0.043842

# %% [markdown]
# ### Right now this logitics model has best performance, save this sparse data

# %%
from scipy import sparse

y = y_train.reshape(-1,1)
train_session_npz = hstack([new_train_addYMD, y])
test_session_npz = new_test_addYMD

sparse.save_npz('train_session.npz', train_session_npz)
sparse.save_npz('test_session.npz', test_session_npz)

# %% [markdown]
# ### Grid Search fine tuning for Xgboost

# %%
m = new_train_addYMD.tocsr()
n = new_test_addYMD.tocsr()

xgb_train = m[:int(new_train_addYMD.shape[0]*0.8),:]
xgb_train_y = y_train[:int(y_train.shape[0]*0.8)]

xgb_test = m[int(new_train_addYMD.shape[0]*0.8):,:]
xgb_test_y = y_train[int(y_train.shape[0]*0.8):]

eval_set = [(xgb_train,xgb_train_y),(xgb_test, xgb_test_y)]

# %%
# first let's see how much iteration(# of trees) we need for model

eval_metric = ['auc', 'error']
model = XGBClassifier(slient=False,
                     scale_pos_weight=1,
                     learning_rate=0.01,
                     colsample_bytree=0.4,
                     subsample=0.8,
                     objective='binary:logistic',
                     n_estimators=1000,
                     reg_alpha=0.3,
                     max_depth=4,
                     gamma=10)

# %% [markdown]
# #### decide the number of tree (n_estimators), first fix params of tree structure and fix learning_rate in a high value(0.1)

# %%
# %time
model.fit(new_train_addYMD, y_train, eval_metric=eval_metric, eval_set=eval_set, verbose=True)
# Out:
# Wall time: 0 ns
# [0]	validation_0-auc:0.677147	validation_0-error:0.009441	validation_1-auc:0.646088	validation_1-error:0.00629
# [1]	validation_0-auc:0.708712	validation_0-error:0.009352	validation_1-auc:0.672415	validation_1-error:0.00631
# [2]	validation_0-auc:0.731216	validation_0-error:0.008627	validation_1-auc:0.69538	validation_1-error:0.006389
# [3]	validation_0-auc:0.742067	validation_0-error:0.008652	validation_1-auc:0.705017	validation_1-error:0.00633
# [4]	validation_0-auc:0.741873	validation_0-error:0.008667	validation_1-auc:0.704865	validation_1-error:0.006389
# [5]	validation_0-auc:0.741868	validation_0-error:0.008652	validation_1-auc:0.704827	validation_1-error:0.006369
# [6]	validation_0-auc:0.749725	validation_0-error:0.00951	validation_1-auc:0.707504	validation_1-error:0.006369
# [7]	validation_0-auc:0.748653	validation_0-error:0.009662	validation_1-auc:0.706613	validation_1-error:0.006369
# [8]	validation_0-auc:0.753452	validation_0-error:0.009677	validation_1-auc:0.708064	validation_1-error:0.006389
# [9]	validation_0-auc:0.858501	validation_0-error:0.009653	validation_1-auc:0.839993	validation_1-error:0.006389
# [10]	validation_0-auc:0.858605	validation_0-error:0.009623	validation_1-auc:0.840208	validation_1-error:0.006369
# [11]	validation_0-auc:0.858859	validation_0-error:0.009653	validation_1-auc:0.840464	validation_1-error:0.006389
# [12]	validation_0-auc:0.859132	validation_0-error:0.009677	validation_1-auc:0.841264	validation_1-error:0.006389
# [13]	validation_0-auc:0.859134	validation_0-error:0.009692	validation_1-auc:0.841245	validation_1-error:0.006389
# [14]	validation_0-auc:0.859327	validation_0-error:0.009381	validation_1-auc:0.841359	validation_1-error:0.006389
# [15]	validation_0-auc:0.859237	validation_0-error:0.008829	validation_1-auc:0.841247	validation_1-error:0.006389
# [16]	validation_0-auc:0.859111	validation_0-error:0.009519	validation_1-auc:0.841069	validation_1-error:0.006389
# [17]	validation_0-auc:0.860064	validation_0-error:0.009618	validation_1-auc:0.84125	validation_1-error:0.006389
# [18]	validation_0-auc:0.860631	validation_0-error:0.009515	validation_1-auc:0.84128	validation_1-error:0.006389
# [19]	validation_0-auc:0.863335	validation_0-error:0.008849	validation_1-auc:0.841381	validation_1-error:0.006389
# [20]	validation_0-auc:0.863265	validation_0-error:0.008819	validation_1-auc:0.841284	validation_1-error:0.006389
# [21]	validation_0-auc:0.863599	validation_0-error:0.008854	validation_1-auc:0.841315	validation_1-error:0.006389
# [22]	validation_0-auc:0.863859	validation_0-error:0.009539	validation_1-auc:0.841231	validation_1-error:0.006389
# [23]	validation_0-auc:0.863858	validation_0-error:0.009337	validation_1-auc:0.841237	validation_1-error:0.006389
# [24]	validation_0-auc:0.865692	validation_0-error:0.009524	validation_1-auc:0.841229	validation_1-error:0.006389
# [25]	validation_0-auc:0.865659	validation_0-error:0.009588	validation_1-auc:0.841135	validation_1-error:0.006389
# [26]	validation_0-auc:0.865641	validation_0-error:0.009608	validation_1-auc:0.841084	validation_1-error:0.006389
# [27]	validation_0-auc:0.86572	validation_0-error:0.009608	validation_1-auc:0.841219	validation_1-error:0.006389
# [28]	validation_0-auc:0.867004	validation_0-error:0.009618	validation_1-auc:0.841902	validation_1-error:0.006389
# [29]	validation_0-auc:0.866952	validation_0-error:0.009618	validation_1-auc:0.841829	validation_1-error:0.006389
# [30]	validation_0-auc:0.866644	validation_0-error:0.009653	validation_1-auc:0.841983	validation_1-error:0.006389
# [31]	validation_0-auc:0.867324	validation_0-error:0.009623	validation_1-auc:0.841964	validation_1-error:0.006389
# [32]	validation_0-auc:0.867308	validation_0-error:0.009657	validation_1-auc:0.841929	validation_1-error:0.006389
# [33]	validation_0-auc:0.867218	validation_0-error:0.009657	validation_1-auc:0.841863	validation_1-error:0.006389
# [34]	validation_0-auc:0.869438	validation_0-error:0.009657	validation_1-auc:0.844815	validation_1-error:0.006389
# [35]	validation_0-auc:0.869379	validation_0-error:0.009638	validation_1-auc:0.844776	validation_1-error:0.006389
# [36]	validation_0-auc:0.872397	validation_0-error:0.009653	validation_1-auc:0.845095	validation_1-error:0.006389
# [37]	validation_0-auc:0.872401	validation_0-error:0.009648	validation_1-auc:0.845126	validation_1-error:0.006389
# [38]	validation_0-auc:0.8724	validation_0-error:0.009628	validation_1-auc:0.84512	validation_1-error:0.006389
# [39]	validation_0-auc:0.872386	validation_0-error:0.009623	validation_1-auc:0.84512	validation_1-error:0.006389
# [40]	validation_0-auc:0.869905	validation_0-error:0.009623	validation_1-auc:0.841866	validation_1-error:0.006389
# [41]	validation_0-auc:0.869877	validation_0-error:0.009618	validation_1-auc:0.841851	validation_1-error:0.006389
# [42]	validation_0-auc:0.869637	validation_0-error:0.009628	validation_1-auc:0.841727	validation_1-error:0.006389
# [43]	validation_0-auc:0.869801	validation_0-error:0.009628	validation_1-auc:0.841808	validation_1-error:0.006389
# [44]	validation_0-auc:0.869789	validation_0-error:0.009618	validation_1-auc:0.84181	validation_1-error:0.006389
# [45]	validation_0-auc:0.869785	validation_0-error:0.009623	validation_1-auc:0.841806	validation_1-error:0.006389
# [46]	validation_0-auc:0.869958	validation_0-error:0.009613	validation_1-auc:0.84175	validation_1-error:0.006389
# [47]	validation_0-auc:0.870166	validation_0-error:0.009603	validation_1-auc:0.841937	validation_1-error:0.006389
# [48]	validation_0-auc:0.870269	validation_0-error:0.009603	validation_1-auc:0.84198	validation_1-error:0.006389
# [49]	validation_0-auc:0.870346	validation_0-error:0.009593	validation_1-auc:0.841935	validation_1-error:0.006389
# [50]	validation_0-auc:0.871043	validation_0-error:0.009598	validation_1-auc:0.842331	validation_1-error:0.006389
# [51]	validation_0-auc:0.871647	validation_0-error:0.009598	validation_1-auc:0.843906	validation_1-error:0.006389
# [52]	validation_0-auc:0.871479	validation_0-error:0.009598	validation_1-auc:0.843709	validation_1-error:0.006389
# [53]	validation_0-auc:0.871782	validation_0-error:0.009593	validation_1-auc:0.843862	validation_1-error:0.006389
# [54]	validation_0-auc:0.871787	validation_0-error:0.009598	validation_1-auc:0.843859	validation_1-error:0.006389
# [55]	validation_0-auc:0.872908	validation_0-error:0.009598	validation_1-auc:0.845894	validation_1-error:0.006389
# [56]	validation_0-auc:0.872871	validation_0-error:0.009603	validation_1-auc:0.845871	validation_1-error:0.006389
# [57]	validation_0-auc:0.872833	validation_0-error:0.009613	validation_1-auc:0.845851	validation_1-error:0.006389
# [58]	validation_0-auc:0.872332	validation_0-error:0.009613	validation_1-auc:0.845568	validation_1-error:0.006389
# [59]	validation_0-auc:0.87234	validation_0-error:0.009613	validation_1-auc:0.845556	validation_1-error:0.006389
# [60]	validation_0-auc:0.872318	validation_0-error:0.009618	validation_1-auc:0.845526	validation_1-error:0.006389
# [61]	validation_0-auc:0.870856	validation_0-error:0.009613	validation_1-auc:0.843473	validation_1-error:0.006389
# [62]	validation_0-auc:0.870895	validation_0-error:0.009613	validation_1-auc:0.843496	validation_1-error:0.006389
# [63]	validation_0-auc:0.870888	validation_0-error:0.009608	validation_1-auc:0.843468	validation_1-error:0.006389
# [64]	validation_0-auc:0.870925	validation_0-error:0.009608	validation_1-auc:0.843458	validation_1-error:0.006389
# [65]	validation_0-auc:0.871056	validation_0-error:0.009608	validation_1-auc:0.843458	validation_1-error:0.006389
# [66]	validation_0-auc:0.871029	validation_0-error:0.009618	validation_1-auc:0.843447	validation_1-error:0.006389
# [67]	validation_0-auc:0.871187	validation_0-error:0.009618	validation_1-auc:0.843482	validation_1-error:0.006389
# [68]	validation_0-auc:0.871178	validation_0-error:0.009613	validation_1-auc:0.84347	validation_1-error:0.006389
# [69]	validation_0-auc:0.871197	validation_0-error:0.009618	validation_1-auc:0.843466	validation_1-error:0.006389
# [70]	validation_0-auc:0.871197	validation_0-error:0.009618	validation_1-auc:0.843476	validation_1-error:0.006389
# [71]	validation_0-auc:0.871199	validation_0-error:0.009618	validation_1-auc:0.84345	validation_1-error:0.006389
# [72]	validation_0-auc:0.871252	validation_0-error:0.009613	validation_1-auc:0.843458	validation_1-error:0.006389
# [73]	validation_0-auc:0.871236	validation_0-error:0.009608	validation_1-auc:0.843468	validation_1-error:0.006389
# [74]	validation_0-auc:0.87119	validation_0-error:0.009608	validation_1-auc:0.843425	validation_1-error:0.006389
# [75]	validation_0-auc:0.87117	validation_0-error:0.009603	validation_1-auc:0.843421	validation_1-error:0.006389
# [76]	validation_0-auc:0.871201	validation_0-error:0.009608	validation_1-auc:0.843512	validation_1-error:0.006389
# [77]	validation_0-auc:0.871175	validation_0-error:0.009608	validation_1-auc:0.843494	validation_1-error:0.006389
# [78]	validation_0-auc:0.87118	validation_0-error:0.009608	validation_1-auc:0.843476	validation_1-error:0.006389
# [79]	validation_0-auc:0.87123	validation_0-error:0.009608	validation_1-auc:0.843515	validation_1-error:0.006389
# [80]	validation_0-auc:0.871203	validation_0-error:0.009603	validation_1-auc:0.843481	validation_1-error:0.006389
# [81]	validation_0-auc:0.871208	validation_0-error:0.009603	validation_1-auc:0.843486	validation_1-error:0.006389
# [82]	validation_0-auc:0.87249	validation_0-error:0.009603	validation_1-auc:0.845513	validation_1-error:0.006389
# [83]	validation_0-auc:0.871504	validation_0-error:0.009608	validation_1-auc:0.844064	validation_1-error:0.006389
# [84]	validation_0-auc:0.87159	validation_0-error:0.009613	validation_1-auc:0.844039	validation_1-error:0.006389
# [85]	validation_0-auc:0.871565	validation_0-error:0.009608	validation_1-auc:0.844021	validation_1-error:0.006389
# [86]	validation_0-auc:0.871549	validation_0-error:0.009613	validation_1-auc:0.844002	validation_1-error:0.006389
# [87]	validation_0-auc:0.87056	validation_0-error:0.009608	validation_1-auc:0.843436	validation_1-error:0.006389
# [88]	validation_0-auc:0.870546	validation_0-error:0.009598	validation_1-auc:0.84342	validation_1-error:0.006389
# [89]	validation_0-auc:0.870576	validation_0-error:0.009598	validation_1-auc:0.843416	validation_1-error:0.006389
# [90]	validation_0-auc:0.870564	validation_0-error:0.009598	validation_1-auc:0.843402	validation_1-error:0.006389
# [91]	validation_0-auc:0.870539	validation_0-error:0.009598	validation_1-auc:0.843376	validation_1-error:0.006389
# [92]	validation_0-auc:0.870517	validation_0-error:0.009598	validation_1-auc:0.843349	validation_1-error:0.006389
# [93]	validation_0-auc:0.870777	validation_0-error:0.009598	validation_1-auc:0.844334	validation_1-error:0.006389
# [94]	validation_0-auc:0.871686	validation_0-error:0.009593	validation_1-auc:0.844915	validation_1-error:0.006389
# [95]	validation_0-auc:0.871668	validation_0-error:0.009598	validation_1-auc:0.844926	validation_1-error:0.006389
# [96]	validation_0-auc:0.871675	validation_0-error:0.009598	validation_1-auc:0.844941	validation_1-error:0.006389
# [97]	validation_0-auc:0.871678	validation_0-error:0.009598	validation_1-auc:0.844944	validation_1-error:0.006389
# [98]	validation_0-auc:0.871871	validation_0-error:0.009603	validation_1-auc:0.845027	validation_1-error:0.006389
# [99]	validation_0-auc:0.871889	validation_0-error:0.009593	validation_1-auc:0.845047	validation_1-error:0.006389
# [100]	validation_0-auc:0.871865	validation_0-error:0.009593	validation_1-auc:0.845044	validation_1-error:0.006389
# [101]	validation_0-auc:0.87185	validation_0-error:0.009598	validation_1-auc:0.845128	validation_1-error:0.006389
# [102]	validation_0-auc:0.872348	validation_0-error:0.009598	validation_1-auc:0.845922	validation_1-error:0.006389
# [103]	validation_0-auc:0.872952	validation_0-error:0.009603	validation_1-auc:0.847438	validation_1-error:0.006389
# [104]	validation_0-auc:0.873021	validation_0-error:0.009588	validation_1-auc:0.847477	validation_1-error:0.006389
# [105]	validation_0-auc:0.872944	validation_0-error:0.009598	validation_1-auc:0.84744	validation_1-error:0.006389
# [106]	validation_0-auc:0.872923	validation_0-error:0.009593	validation_1-auc:0.847422	validation_1-error:0.006389
# [107]	validation_0-auc:0.873012	validation_0-error:0.009588	validation_1-auc:0.84743	validation_1-error:0.006389
# [108]	validation_0-auc:0.873016	validation_0-error:0.009584	validation_1-auc:0.847426	validation_1-error:0.006389
# [109]	validation_0-auc:0.872921	validation_0-error:0.009593	validation_1-auc:0.846809	validation_1-error:0.006389
# [110]	validation_0-auc:0.872925	validation_0-error:0.009593	validation_1-auc:0.846809	validation_1-error:0.006389
# [111]	validation_0-auc:0.872977	validation_0-error:0.009584	validation_1-auc:0.846814	validation_1-error:0.006389
# [112]	validation_0-auc:0.873009	validation_0-error:0.009574	validation_1-auc:0.846876	validation_1-error:0.006389
# [113]	validation_0-auc:0.872987	validation_0-error:0.009569	validation_1-auc:0.846849	validation_1-error:0.006389
# [114]	validation_0-auc:0.873158	validation_0-error:0.009564	validation_1-auc:0.846915	validation_1-error:0.006389
# [115]	validation_0-auc:0.873203	validation_0-error:0.009559	validation_1-auc:0.846936	validation_1-error:0.006389
# [116]	validation_0-auc:0.873317	validation_0-error:0.009539	validation_1-auc:0.84691	validation_1-error:0.006389
# [117]	validation_0-auc:0.873306	validation_0-error:0.009544	validation_1-auc:0.846894	validation_1-error:0.006389
# [118]	validation_0-auc:0.873662	validation_0-error:0.009475	validation_1-auc:0.847458	validation_1-error:0.006389
# [119]	validation_0-auc:0.873652	validation_0-error:0.00949	validation_1-auc:0.847442	validation_1-error:0.006389
# [120]	validation_0-auc:0.872655	validation_0-error:0.00951	validation_1-auc:0.847382	validation_1-error:0.006389
# [121]	validation_0-auc:0.873337	validation_0-error:0.009549	validation_1-auc:0.84738	validation_1-error:0.006389
# [122]	validation_0-auc:0.873359	validation_0-error:0.009549	validation_1-auc:0.847393	validation_1-error:0.006389
# [123]	validation_0-auc:0.873396	validation_0-error:0.009495	validation_1-auc:0.84749	validation_1-error:0.006389
# [124]	validation_0-auc:0.873404	validation_0-error:0.009515	validation_1-auc:0.84749	validation_1-error:0.006389
# [125]	validation_0-auc:0.873386	validation_0-error:0.009515	validation_1-auc:0.847469	validation_1-error:0.006389
# [126]	validation_0-auc:0.873689	validation_0-error:0.009455	validation_1-auc:0.84748	validation_1-error:0.006369
# [127]	validation_0-auc:0.873651	validation_0-error:0.009465	validation_1-auc:0.847465	validation_1-error:0.006369
# [128]	validation_0-auc:0.873675	validation_0-error:0.009441	validation_1-auc:0.847495	validation_1-error:0.006369
# [129]	validation_0-auc:0.873663	validation_0-error:0.009426	validation_1-auc:0.847471	validation_1-error:0.006369
# [130]	validation_0-auc:0.873653	validation_0-error:0.009426	validation_1-auc:0.847468	validation_1-error:0.006369
# [131]	validation_0-auc:0.873638	validation_0-error:0.009421	validation_1-auc:0.847402	validation_1-error:0.006369
# [132]	validation_0-auc:0.873662	validation_0-error:0.009416	validation_1-auc:0.847476	validation_1-error:0.006369
# [133]	validation_0-auc:0.873677	validation_0-error:0.009426	validation_1-auc:0.847465	validation_1-error:0.006369
# [134]	validation_0-auc:0.873789	validation_0-error:0.009416	validation_1-auc:0.847452	validation_1-error:0.006369
# [135]	validation_0-auc:0.875064	validation_0-error:0.009322	validation_1-auc:0.847503	validation_1-error:0.006369
# [136]	validation_0-auc:0.875024	validation_0-error:0.009209	validation_1-auc:0.847491	validation_1-error:0.006369
# [137]	validation_0-auc:0.875005	validation_0-error:0.0091	validation_1-auc:0.847487	validation_1-error:0.006369
# [138]	validation_0-auc:0.875273	validation_0-error:0.009174	validation_1-auc:0.847486	validation_1-error:0.006369
# [139]	validation_0-auc:0.875326	validation_0-error:0.009086	validation_1-auc:0.847518	validation_1-error:0.006369
# [140]	validation_0-auc:0.875333	validation_0-error:0.009105	validation_1-auc:0.847498	validation_1-error:0.006369
# [141]	validation_0-auc:0.875314	validation_0-error:0.0091	validation_1-auc:0.847484	validation_1-error:0.006369
# [142]	validation_0-auc:0.875305	validation_0-error:0.00915	validation_1-auc:0.847481	validation_1-error:0.006369
# [143]	validation_0-auc:0.876826	validation_0-error:0.009061	validation_1-auc:0.847463	validation_1-error:0.006369
# [144]	validation_0-auc:0.877722	validation_0-error:0.009086	validation_1-auc:0.852894	validation_1-error:0.006369
# [145]	validation_0-auc:0.879441	validation_0-error:0.009105	validation_1-auc:0.857537	validation_1-error:0.006369
# [146]	validation_0-auc:0.879441	validation_0-error:0.009066	validation_1-auc:0.85754	validation_1-error:0.006369
# [147]	validation_0-auc:0.87978	validation_0-error:0.009066	validation_1-auc:0.857952	validation_1-error:0.006369
# [148]	validation_0-auc:0.880943	validation_0-error:0.009051	validation_1-auc:0.859151	validation_1-error:0.006369
# [149]	validation_0-auc:0.880941	validation_0-error:0.009046	validation_1-auc:0.859118	validation_1-error:0.006369
# [150]	validation_0-auc:0.881176	validation_0-error:0.009056	validation_1-auc:0.859225	validation_1-error:0.006369
# [151]	validation_0-auc:0.881164	validation_0-error:0.009051	validation_1-auc:0.859939	validation_1-error:0.006369
# [152]	validation_0-auc:0.881434	validation_0-error:0.008982	validation_1-auc:0.860358	validation_1-error:0.006369
# [153]	validation_0-auc:0.881833	validation_0-error:0.008721	validation_1-auc:0.860802	validation_1-error:0.006369
# [154]	validation_0-auc:0.881847	validation_0-error:0.00879	validation_1-auc:0.860816	validation_1-error:0.006369
# [155]	validation_0-auc:0.882017	validation_0-error:0.00878	validation_1-auc:0.860738	validation_1-error:0.006369
# [156]	validation_0-auc:0.882438	validation_0-error:0.008681	validation_1-auc:0.86104	validation_1-error:0.006369
# [157]	validation_0-auc:0.882353	validation_0-error:0.008686	validation_1-auc:0.860965	validation_1-error:0.006369
# [158]	validation_0-auc:0.882694	validation_0-error:0.008681	validation_1-auc:0.861569	validation_1-error:0.006369
# [159]	validation_0-auc:0.882638	validation_0-error:0.008676	validation_1-auc:0.863045	validation_1-error:0.006369
# [160]	validation_0-auc:0.882796	validation_0-error:0.008667	validation_1-auc:0.863143	validation_1-error:0.006369
# [161]	validation_0-auc:0.904947	validation_0-error:0.008691	validation_1-auc:0.91081	validation_1-error:0.006369
# [162]	validation_0-auc:0.905102	validation_0-error:0.008667	validation_1-auc:0.910908	validation_1-error:0.006369
# [163]	validation_0-auc:0.905225	validation_0-error:0.008667	validation_1-auc:0.910967	validation_1-error:0.006369
# [164]	validation_0-auc:0.90555	validation_0-error:0.008681	validation_1-auc:0.910982	validation_1-error:0.006369
# [165]	validation_0-auc:0.905598	validation_0-error:0.008662	validation_1-auc:0.911086	validation_1-error:0.006369
# [166]	validation_0-auc:0.905411	validation_0-error:0.008667	validation_1-auc:0.910883	validation_1-error:0.006369
# [167]	validation_0-auc:0.905444	validation_0-error:0.008667	validation_1-auc:0.910892	validation_1-error:0.006369
# [168]	validation_0-auc:0.905355	validation_0-error:0.008657	validation_1-auc:0.910808	validation_1-error:0.006369
# [169]	validation_0-auc:0.90534	validation_0-error:0.008676	validation_1-auc:0.910666	validation_1-error:0.006369
# [170]	validation_0-auc:0.9049	validation_0-error:0.008662	validation_1-auc:0.910769	validation_1-error:0.006369
# [171]	validation_0-auc:0.904918	validation_0-error:0.008672	validation_1-auc:0.910803	validation_1-error:0.006369
# [172]	validation_0-auc:0.904916	validation_0-error:0.008662	validation_1-auc:0.910793	validation_1-error:0.006369
# [173]	validation_0-auc:0.904951	validation_0-error:0.008662	validation_1-auc:0.910827	validation_1-error:0.006369
# [174]	validation_0-auc:0.905082	validation_0-error:0.008662	validation_1-auc:0.910916	validation_1-error:0.006369
# [175]	validation_0-auc:0.905238	validation_0-error:0.008652	validation_1-auc:0.911073	validation_1-error:0.006369
# [176]	validation_0-auc:0.905558	validation_0-error:0.008642	validation_1-auc:0.911116	validation_1-error:0.006369
# [177]	validation_0-auc:0.905524	validation_0-error:0.008642	validation_1-auc:0.911157	validation_1-error:0.006369
# [178]	validation_0-auc:0.906545	validation_0-error:0.008647	validation_1-auc:0.91362	validation_1-error:0.006369
# [179]	validation_0-auc:0.906422	validation_0-error:0.008652	validation_1-auc:0.91356	validation_1-error:0.006369
# [180]	validation_0-auc:0.906247	validation_0-error:0.008652	validation_1-auc:0.913426	validation_1-error:0.006369
# [181]	validation_0-auc:0.906751	validation_0-error:0.008662	validation_1-auc:0.91433	validation_1-error:0.006369
# [182]	validation_0-auc:0.90689	validation_0-error:0.008657	validation_1-auc:0.914418	validation_1-error:0.006369
# [183]	validation_0-auc:0.90687	validation_0-error:0.008662	validation_1-auc:0.914483	validation_1-error:0.006369
# [184]	validation_0-auc:0.906848	validation_0-error:0.008662	validation_1-auc:0.914487	validation_1-error:0.006369
# [185]	validation_0-auc:0.906785	validation_0-error:0.008667	validation_1-auc:0.914953	validation_1-error:0.006369
# [186]	validation_0-auc:0.906676	validation_0-error:0.008662	validation_1-auc:0.914928	validation_1-error:0.006369
# [187]	validation_0-auc:0.906795	validation_0-error:0.008657	validation_1-auc:0.914984	validation_1-error:0.006369
# [188]	validation_0-auc:0.90924	validation_0-error:0.008662	validation_1-auc:0.915031	validation_1-error:0.006369
# [189]	validation_0-auc:0.90922	validation_0-error:0.008652	validation_1-auc:0.915096	validation_1-error:0.006369
# [190]	validation_0-auc:0.909317	validation_0-error:0.008627	validation_1-auc:0.915195	validation_1-error:0.006369
# [191]	validation_0-auc:0.909619	validation_0-error:0.008627	validation_1-auc:0.915155	validation_1-error:0.006369
# [192]	validation_0-auc:0.909644	validation_0-error:0.008647	validation_1-auc:0.915243	validation_1-error:0.006369
# [193]	validation_0-auc:0.909845	validation_0-error:0.008647	validation_1-auc:0.914862	validation_1-error:0.006369
# [194]	validation_0-auc:0.909938	validation_0-error:0.008647	validation_1-auc:0.915039	validation_1-error:0.006369
# [195]	validation_0-auc:0.90996	validation_0-error:0.008637	validation_1-auc:0.915056	validation_1-error:0.006369
# [196]	validation_0-auc:0.910055	validation_0-error:0.008642	validation_1-auc:0.915088	validation_1-error:0.006369
# [197]	validation_0-auc:0.909909	validation_0-error:0.008637	validation_1-auc:0.914985	validation_1-error:0.006369
# [198]	validation_0-auc:0.920014	validation_0-error:0.008627	validation_1-auc:0.915163	validation_1-error:0.006369
# [199]	validation_0-auc:0.919853	validation_0-error:0.008622	validation_1-auc:0.914951	validation_1-error:0.006369
# [200]	validation_0-auc:0.919962	validation_0-error:0.008627	validation_1-auc:0.915124	validation_1-error:0.006369
# [201]	validation_0-auc:0.920026	validation_0-error:0.008632	validation_1-auc:0.915118	validation_1-error:0.006369
# [202]	validation_0-auc:0.91996	validation_0-error:0.008627	validation_1-auc:0.915086	validation_1-error:0.006369
# [203]	validation_0-auc:0.919726	validation_0-error:0.008627	validation_1-auc:0.914852	validation_1-error:0.006369
# [204]	validation_0-auc:0.919569	validation_0-error:0.008617	validation_1-auc:0.914715	validation_1-error:0.006369
# [205]	validation_0-auc:0.919377	validation_0-error:0.008617	validation_1-auc:0.914425	validation_1-error:0.006369
# [206]	validation_0-auc:0.919763	validation_0-error:0.008627	validation_1-auc:0.91476	validation_1-error:0.006369
# [207]	validation_0-auc:0.919496	validation_0-error:0.008617	validation_1-auc:0.914793	validation_1-error:0.006369
# [208]	validation_0-auc:0.919351	validation_0-error:0.008617	validation_1-auc:0.914839	validation_1-error:0.006369
# [209]	validation_0-auc:0.919425	validation_0-error:0.008612	validation_1-auc:0.914936	validation_1-error:0.006369
# [210]	validation_0-auc:0.918637	validation_0-error:0.008607	validation_1-auc:0.915194	validation_1-error:0.006369
# [211]	validation_0-auc:0.918613	validation_0-error:0.008602	validation_1-auc:0.915147	validation_1-error:0.006369
# [212]	validation_0-auc:0.918692	validation_0-error:0.008602	validation_1-auc:0.91523	validation_1-error:0.006369
# [213]	validation_0-auc:0.918603	validation_0-error:0.008593	validation_1-auc:0.915179	validation_1-error:0.006369
# [214]	validation_0-auc:0.918607	validation_0-error:0.008593	validation_1-auc:0.915264	validation_1-error:0.006369
# [215]	validation_0-auc:0.918142	validation_0-error:0.008598	validation_1-auc:0.916599	validation_1-error:0.006369
# [216]	validation_0-auc:0.918209	validation_0-error:0.008578	validation_1-auc:0.916731	validation_1-error:0.006369
# [217]	validation_0-auc:0.91835	validation_0-error:0.008593	validation_1-auc:0.916756	validation_1-error:0.006369
# [218]	validation_0-auc:0.918405	validation_0-error:0.008593	validation_1-auc:0.916918	validation_1-error:0.006369
# [219]	validation_0-auc:0.918281	validation_0-error:0.008593	validation_1-auc:0.916527	validation_1-error:0.006369
# [220]	validation_0-auc:0.918409	validation_0-error:0.008598	validation_1-auc:0.916785	validation_1-error:0.006369
# [221]	validation_0-auc:0.91845	validation_0-error:0.008602	validation_1-auc:0.916972	validation_1-error:0.006369
# [222]	validation_0-auc:0.918503	validation_0-error:0.008598	validation_1-auc:0.91711	validation_1-error:0.006369
# [223]	validation_0-auc:0.918547	validation_0-error:0.008583	validation_1-auc:0.917213	validation_1-error:0.006369
# [224]	validation_0-auc:0.918454	validation_0-error:0.008578	validation_1-auc:0.91713	validation_1-error:0.006369
# [225]	validation_0-auc:0.918378	validation_0-error:0.008588	validation_1-auc:0.917075	validation_1-error:0.006369
# [226]	validation_0-auc:0.918409	validation_0-error:0.008573	validation_1-auc:0.917163	validation_1-error:0.006369
# [227]	validation_0-auc:0.918362	validation_0-error:0.008573	validation_1-auc:0.927667	validation_1-error:0.006369
# [228]	validation_0-auc:0.918656	validation_0-error:0.008573	validation_1-auc:0.92734	validation_1-error:0.006369
# [229]	validation_0-auc:0.919003	validation_0-error:0.008578	validation_1-auc:0.927481	validation_1-error:0.006369
# [230]	validation_0-auc:0.918989	validation_0-error:0.008573	validation_1-auc:0.927969	validation_1-error:0.006369
# [231]	validation_0-auc:0.919078	validation_0-error:0.008578	validation_1-auc:0.927984	validation_1-error:0.006369
# [232]	validation_0-auc:0.919201	validation_0-error:0.008588	validation_1-auc:0.92813	validation_1-error:0.006369
# [233]	validation_0-auc:0.919094	validation_0-error:0.008573	validation_1-auc:0.928077	validation_1-error:0.006369
# [234]	validation_0-auc:0.924091	validation_0-error:0.008568	validation_1-auc:0.941191	validation_1-error:0.006369
# [235]	validation_0-auc:0.924323	validation_0-error:0.008578	validation_1-auc:0.94101	validation_1-error:0.006369
# [236]	validation_0-auc:0.924413	validation_0-error:0.008568	validation_1-auc:0.941051	validation_1-error:0.006369
# [237]	validation_0-auc:0.924294	validation_0-error:0.008568	validation_1-auc:0.940855	validation_1-error:0.006369
# [238]	validation_0-auc:0.924259	validation_0-error:0.008573	validation_1-auc:0.941014	validation_1-error:0.006369
# [239]	validation_0-auc:0.924146	validation_0-error:0.008578	validation_1-auc:0.941048	validation_1-error:0.006369
# [240]	validation_0-auc:0.924177	validation_0-error:0.008573	validation_1-auc:0.9411	validation_1-error:0.006369
# [241]	validation_0-auc:0.924219	validation_0-error:0.008568	validation_1-auc:0.941181	validation_1-error:0.006369
# [242]	validation_0-auc:0.924289	validation_0-error:0.008573	validation_1-auc:0.941209	validation_1-error:0.006369
# [243]	validation_0-auc:0.924583	validation_0-error:0.008568	validation_1-auc:0.937985	validation_1-error:0.006369
# [244]	validation_0-auc:0.924247	validation_0-error:0.008573	validation_1-auc:0.938129	validation_1-error:0.006369
# [245]	validation_0-auc:0.924294	validation_0-error:0.008573	validation_1-auc:0.938165	validation_1-error:0.006369
# [246]	validation_0-auc:0.924502	validation_0-error:0.008573	validation_1-auc:0.939647	validation_1-error:0.006369
# [247]	validation_0-auc:0.925286	validation_0-error:0.008568	validation_1-auc:0.939701	validation_1-error:0.006369
# [248]	validation_0-auc:0.925201	validation_0-error:0.008553	validation_1-auc:0.939589	validation_1-error:0.006369
# [249]	validation_0-auc:0.925149	validation_0-error:0.008553	validation_1-auc:0.939504	validation_1-error:0.006369
# [250]	validation_0-auc:0.925178	validation_0-error:0.008543	validation_1-auc:0.93948	validation_1-error:0.006369
# [251]	validation_0-auc:0.925228	validation_0-error:0.008548	validation_1-auc:0.939464	validation_1-error:0.006369
# [252]	validation_0-auc:0.925253	validation_0-error:0.008548	validation_1-auc:0.939496	validation_1-error:0.006369
# [253]	validation_0-auc:0.925292	validation_0-error:0.008538	validation_1-auc:0.939528	validation_1-error:0.006369
# [254]	validation_0-auc:0.92533	validation_0-error:0.008543	validation_1-auc:0.939474	validation_1-error:0.006369
# [255]	validation_0-auc:0.925528	validation_0-error:0.008558	validation_1-auc:0.940276	validation_1-error:0.006369
# [256]	validation_0-auc:0.92544	validation_0-error:0.008553	validation_1-auc:0.940237	validation_1-error:0.006369
# [257]	validation_0-auc:0.925689	validation_0-error:0.008553	validation_1-auc:0.941039	validation_1-error:0.006369
# [258]	validation_0-auc:0.925693	validation_0-error:0.008543	validation_1-auc:0.941055	validation_1-error:0.006369
# [259]	validation_0-auc:0.925725	validation_0-error:0.008543	validation_1-auc:0.941052	validation_1-error:0.006369
# [260]	validation_0-auc:0.925646	validation_0-error:0.008548	validation_1-auc:0.941222	validation_1-error:0.006369
# [261]	validation_0-auc:0.925671	validation_0-error:0.008548	validation_1-auc:0.941228	validation_1-error:0.006369
# [262]	validation_0-auc:0.925578	validation_0-error:0.008533	validation_1-auc:0.941147	validation_1-error:0.006369
# [263]	validation_0-auc:0.925777	validation_0-error:0.008538	validation_1-auc:0.941214	validation_1-error:0.006369
# [264]	validation_0-auc:0.925846	validation_0-error:0.008548	validation_1-auc:0.941222	validation_1-error:0.006369
# [265]	validation_0-auc:0.926118	validation_0-error:0.008543	validation_1-auc:0.941328	validation_1-error:0.006369
# [266]	validation_0-auc:0.926006	validation_0-error:0.008543	validation_1-auc:0.94126	validation_1-error:0.006369
# [267]	validation_0-auc:0.925937	validation_0-error:0.008543	validation_1-auc:0.941144	validation_1-error:0.006369
# [268]	validation_0-auc:0.925984	validation_0-error:0.008533	validation_1-auc:0.941133	validation_1-error:0.006369
# [269]	validation_0-auc:0.925982	validation_0-error:0.008543	validation_1-auc:0.941279	validation_1-error:0.006369
# [270]	validation_0-auc:0.926103	validation_0-error:0.008543	validation_1-auc:0.941425	validation_1-error:0.006369
# [271]	validation_0-auc:0.92605	validation_0-error:0.008543	validation_1-auc:0.941387	validation_1-error:0.006349
# [272]	validation_0-auc:0.926114	validation_0-error:0.008533	validation_1-auc:0.94139	validation_1-error:0.006349
# [273]	validation_0-auc:0.926008	validation_0-error:0.008524	validation_1-auc:0.941298	validation_1-error:0.006369
# [274]	validation_0-auc:0.927272	validation_0-error:0.008524	validation_1-auc:0.941164	validation_1-error:0.006349
# [275]	validation_0-auc:0.928483	validation_0-error:0.008524	validation_1-auc:0.941863	validation_1-error:0.006349
# [276]	validation_0-auc:0.928569	validation_0-error:0.008524	validation_1-auc:0.942049	validation_1-error:0.006369
# [277]	validation_0-auc:0.928602	validation_0-error:0.008524	validation_1-auc:0.942026	validation_1-error:0.006369
# [278]	validation_0-auc:0.928654	validation_0-error:0.008504	validation_1-auc:0.94203	validation_1-error:0.006349
# [279]	validation_0-auc:0.928588	validation_0-error:0.008504	validation_1-auc:0.941964	validation_1-error:0.00633
# [280]	validation_0-auc:0.92865	validation_0-error:0.008499	validation_1-auc:0.942147	validation_1-error:0.006349
# [281]	validation_0-auc:0.928727	validation_0-error:0.008489	validation_1-auc:0.942234	validation_1-error:0.00629
# [282]	validation_0-auc:0.928757	validation_0-error:0.008474	validation_1-auc:0.942232	validation_1-error:0.00629
# [283]	validation_0-auc:0.928729	validation_0-error:0.008479	validation_1-auc:0.942194	validation_1-error:0.00629
# [284]	validation_0-auc:0.930583	validation_0-error:0.008479	validation_1-auc:0.942359	validation_1-error:0.00629
# [285]	validation_0-auc:0.930354	validation_0-error:0.008474	validation_1-auc:0.942692	validation_1-error:0.00629
# [286]	validation_0-auc:0.930417	validation_0-error:0.008479	validation_1-auc:0.94281	validation_1-error:0.006271
# [287]	validation_0-auc:0.930515	validation_0-error:0.008479	validation_1-auc:0.942619	validation_1-error:0.006251
# [288]	validation_0-auc:0.930533	validation_0-error:0.008455	validation_1-auc:0.942548	validation_1-error:0.006251
# [289]	validation_0-auc:0.93057	validation_0-error:0.008474	validation_1-auc:0.94256	validation_1-error:0.006271
# [290]	validation_0-auc:0.930536	validation_0-error:0.008474	validation_1-auc:0.94256	validation_1-error:0.006251
# [291]	validation_0-auc:0.930996	validation_0-error:0.008484	validation_1-auc:0.942592	validation_1-error:0.006251
# [292]	validation_0-auc:0.93075	validation_0-error:0.008489	validation_1-auc:0.942698	validation_1-error:0.006251
# [293]	validation_0-auc:0.930759	validation_0-error:0.008474	validation_1-auc:0.942697	validation_1-error:0.006251
# [294]	validation_0-auc:0.931498	validation_0-error:0.008484	validation_1-auc:0.942747	validation_1-error:0.006271
# [295]	validation_0-auc:0.931524	validation_0-error:0.008479	validation_1-auc:0.942849	validation_1-error:0.006251
# [296]	validation_0-auc:0.931525	validation_0-error:0.008464	validation_1-auc:0.942895	validation_1-error:0.006251
# [297]	validation_0-auc:0.931635	validation_0-error:0.00846	validation_1-auc:0.943723	validation_1-error:0.006271
# [298]	validation_0-auc:0.931563	validation_0-error:0.00845	validation_1-auc:0.943646	validation_1-error:0.006271
# [299]	validation_0-auc:0.931592	validation_0-error:0.008445	validation_1-auc:0.943648	validation_1-error:0.006271
# [300]	validation_0-auc:0.933823	validation_0-error:0.008435	validation_1-auc:0.943744	validation_1-error:0.006251
# [301]	validation_0-auc:0.933821	validation_0-error:0.008435	validation_1-auc:0.943742	validation_1-error:0.006271
# [302]	validation_0-auc:0.933761	validation_0-error:0.008435	validation_1-auc:0.943668	validation_1-error:0.006271
# [303]	validation_0-auc:0.933785	validation_0-error:0.008435	validation_1-auc:0.943681	validation_1-error:0.006271
# [304]	validation_0-auc:0.933739	validation_0-error:0.00844	validation_1-auc:0.943813	validation_1-error:0.006271
# [305]	validation_0-auc:0.934016	validation_0-error:0.008435	validation_1-auc:0.943766	validation_1-error:0.006271
# [306]	validation_0-auc:0.934055	validation_0-error:0.00844	validation_1-auc:0.943755	validation_1-error:0.006271
# [307]	validation_0-auc:0.934083	validation_0-error:0.008435	validation_1-auc:0.943731	validation_1-error:0.006231
# [308]	validation_0-auc:0.934224	validation_0-error:0.00844	validation_1-auc:0.943761	validation_1-error:0.006231
# [309]	validation_0-auc:0.934142	validation_0-error:0.00844	validation_1-auc:0.943664	validation_1-error:0.006231
# [310]	validation_0-auc:0.934052	validation_0-error:0.008435	validation_1-auc:0.943613	validation_1-error:0.006231
# [311]	validation_0-auc:0.934041	validation_0-error:0.00843	validation_1-auc:0.943604	validation_1-error:0.006231
# [312]	validation_0-auc:0.934365	validation_0-error:0.00843	validation_1-auc:0.943517	validation_1-error:0.006231
# [313]	validation_0-auc:0.935396	validation_0-error:0.008425	validation_1-auc:0.943454	validation_1-error:0.006231
# [314]	validation_0-auc:0.935801	validation_0-error:0.008425	validation_1-auc:0.943618	validation_1-error:0.006211
# [315]	validation_0-auc:0.935797	validation_0-error:0.008425	validation_1-auc:0.943541	validation_1-error:0.006211
# [316]	validation_0-auc:0.935823	validation_0-error:0.00842	validation_1-auc:0.943536	validation_1-error:0.006231
# [317]	validation_0-auc:0.9362	validation_0-error:0.00842	validation_1-auc:0.943579	validation_1-error:0.006211
# [318]	validation_0-auc:0.936394	validation_0-error:0.00842	validation_1-auc:0.943802	validation_1-error:0.006192
# [319]	validation_0-auc:0.936821	validation_0-error:0.00842	validation_1-auc:0.944096	validation_1-error:0.006192
# [320]	validation_0-auc:0.93681	validation_0-error:0.008415	validation_1-auc:0.944219	validation_1-error:0.006152
# [321]	validation_0-auc:0.93676	validation_0-error:0.008415	validation_1-auc:0.944344	validation_1-error:0.006133
# [322]	validation_0-auc:0.937985	validation_0-error:0.00842	validation_1-auc:0.944797	validation_1-error:0.006133
# [323]	validation_0-auc:0.938225	validation_0-error:0.00842	validation_1-auc:0.944998	validation_1-error:0.006133
# [324]	validation_0-auc:0.938197	validation_0-error:0.00842	validation_1-auc:0.945034	validation_1-error:0.006113
# [325]	validation_0-auc:0.938154	validation_0-error:0.008405	validation_1-auc:0.944975	validation_1-error:0.006113
# [326]	validation_0-auc:0.938106	validation_0-error:0.00841	validation_1-auc:0.944929	validation_1-error:0.006113
# [327]	validation_0-auc:0.937869	validation_0-error:0.008405	validation_1-auc:0.944996	validation_1-error:0.006113
# [328]	validation_0-auc:0.937941	validation_0-error:0.0084	validation_1-auc:0.945143	validation_1-error:0.006113
# [329]	validation_0-auc:0.938813	validation_0-error:0.0084	validation_1-auc:0.946226	validation_1-error:0.006113
# [330]	validation_0-auc:0.938886	validation_0-error:0.008405	validation_1-auc:0.946195	validation_1-error:0.006113
# [331]	validation_0-auc:0.938927	validation_0-error:0.0084	validation_1-auc:0.946212	validation_1-error:0.006113
# [332]	validation_0-auc:0.938373	validation_0-error:0.0084	validation_1-auc:0.946294	validation_1-error:0.006113
# [333]	validation_0-auc:0.9384	validation_0-error:0.008395	validation_1-auc:0.946273	validation_1-error:0.006113
# [334]	validation_0-auc:0.93842	validation_0-error:0.008391	validation_1-auc:0.946213	validation_1-error:0.006113
# [335]	validation_0-auc:0.938524	validation_0-error:0.008391	validation_1-auc:0.94641	validation_1-error:0.006113
# [336]	validation_0-auc:0.938728	validation_0-error:0.008395	validation_1-auc:0.946487	validation_1-error:0.006113
# [337]	validation_0-auc:0.939121	validation_0-error:0.008391	validation_1-auc:0.946543	validation_1-error:0.006113
# [338]	validation_0-auc:0.939013	validation_0-error:0.008391	validation_1-auc:0.946571	validation_1-error:0.006113
# [339]	validation_0-auc:0.940267	validation_0-error:0.008391	validation_1-auc:0.947394	validation_1-error:0.006113
# [340]	validation_0-auc:0.940769	validation_0-error:0.008386	validation_1-auc:0.947579	validation_1-error:0.006113
# [341]	validation_0-auc:0.940736	validation_0-error:0.008386	validation_1-auc:0.947513	validation_1-error:0.006113
# [342]	validation_0-auc:0.940729	validation_0-error:0.008381	validation_1-auc:0.947534	validation_1-error:0.006113
# [343]	validation_0-auc:0.941	validation_0-error:0.008386	validation_1-auc:0.947628	validation_1-error:0.006113
# [344]	validation_0-auc:0.94101	validation_0-error:0.008376	validation_1-auc:0.947587	validation_1-error:0.006113
# [345]	validation_0-auc:0.941598	validation_0-error:0.008381	validation_1-auc:0.949292	validation_1-error:0.006113
# [346]	validation_0-auc:0.941642	validation_0-error:0.008381	validation_1-auc:0.949441	validation_1-error:0.006113
# [347]	validation_0-auc:0.941676	validation_0-error:0.008381	validation_1-auc:0.949504	validation_1-error:0.006113
# [348]	validation_0-auc:0.941667	validation_0-error:0.008381	validation_1-auc:0.949464	validation_1-error:0.006113
# [349]	validation_0-auc:0.941751	validation_0-error:0.008376	validation_1-auc:0.949533	validation_1-error:0.006113
# [350]	validation_0-auc:0.941771	validation_0-error:0.008376	validation_1-auc:0.949748	validation_1-error:0.006113
# [351]	validation_0-auc:0.941914	validation_0-error:0.008381	validation_1-auc:0.949832	validation_1-error:0.006113
# [352]	validation_0-auc:0.941916	validation_0-error:0.008376	validation_1-auc:0.949866	validation_1-error:0.006113
# [353]	validation_0-auc:0.942009	validation_0-error:0.008386	validation_1-auc:0.95004	validation_1-error:0.006113
# [354]	validation_0-auc:0.942204	validation_0-error:0.008381	validation_1-auc:0.950154	validation_1-error:0.006113
# [355]	validation_0-auc:0.942391	validation_0-error:0.008376	validation_1-auc:0.950379	validation_1-error:0.006113
# [356]	validation_0-auc:0.942387	validation_0-error:0.008371	validation_1-auc:0.950179	validation_1-error:0.006113
# [357]	validation_0-auc:0.94257	validation_0-error:0.008366	validation_1-auc:0.950511	validation_1-error:0.006113
# [358]	validation_0-auc:0.942526	validation_0-error:0.008366	validation_1-auc:0.950474	validation_1-error:0.006113
# [359]	validation_0-auc:0.942701	validation_0-error:0.008371	validation_1-auc:0.951383	validation_1-error:0.006113
# [360]	validation_0-auc:0.942721	validation_0-error:0.008371	validation_1-auc:0.951365	validation_1-error:0.006093
# [361]	validation_0-auc:0.942796	validation_0-error:0.008366	validation_1-auc:0.951351	validation_1-error:0.006093
# [362]	validation_0-auc:0.943072	validation_0-error:0.008376	validation_1-auc:0.951382	validation_1-error:0.006093
# [363]	validation_0-auc:0.943091	validation_0-error:0.008371	validation_1-auc:0.951392	validation_1-error:0.006093
# [364]	validation_0-auc:0.943044	validation_0-error:0.008366	validation_1-auc:0.951413	validation_1-error:0.006093
# [365]	validation_0-auc:0.94302	validation_0-error:0.008366	validation_1-auc:0.951355	validation_1-error:0.006093
# [366]	validation_0-auc:0.942976	validation_0-error:0.008366	validation_1-auc:0.95131	validation_1-error:0.006093
# [367]	validation_0-auc:0.942935	validation_0-error:0.008366	validation_1-auc:0.951286	validation_1-error:0.006113
# [368]	validation_0-auc:0.942932	validation_0-error:0.008366	validation_1-auc:0.951323	validation_1-error:0.006093
# [369]	validation_0-auc:0.944365	validation_0-error:0.008366	validation_1-auc:0.951315	validation_1-error:0.006093
# [370]	validation_0-auc:0.944302	validation_0-error:0.008356	validation_1-auc:0.951262	validation_1-error:0.006093
# [371]	validation_0-auc:0.944312	validation_0-error:0.008361	validation_1-auc:0.951415	validation_1-error:0.006073
# [372]	validation_0-auc:0.944548	validation_0-error:0.008361	validation_1-auc:0.951414	validation_1-error:0.006093
# [373]	validation_0-auc:0.945049	validation_0-error:0.008366	validation_1-auc:0.952176	validation_1-error:0.006093
# [374]	validation_0-auc:0.945084	validation_0-error:0.008356	validation_1-auc:0.952141	validation_1-error:0.006093
# [375]	validation_0-auc:0.945142	validation_0-error:0.008366	validation_1-auc:0.952175	validation_1-error:0.006093
# [376]	validation_0-auc:0.945464	validation_0-error:0.008356	validation_1-auc:0.952781	validation_1-error:0.006073
# [377]	validation_0-auc:0.945519	validation_0-error:0.008356	validation_1-auc:0.952854	validation_1-error:0.006054
# [378]	validation_0-auc:0.945505	validation_0-error:0.008356	validation_1-auc:0.952795	validation_1-error:0.006054
# [379]	validation_0-auc:0.945601	validation_0-error:0.008351	validation_1-auc:0.95276	validation_1-error:0.006054
# [380]	validation_0-auc:0.945608	validation_0-error:0.008351	validation_1-auc:0.952744	validation_1-error:0.006054
# [381]	validation_0-auc:0.945653	validation_0-error:0.008356	validation_1-auc:0.952845	validation_1-error:0.006054
# [382]	validation_0-auc:0.945641	validation_0-error:0.008351	validation_1-auc:0.952815	validation_1-error:0.006054
# [383]	validation_0-auc:0.945554	validation_0-error:0.008341	validation_1-auc:0.952807	validation_1-error:0.006054
# [384]	validation_0-auc:0.945883	validation_0-error:0.008336	validation_1-auc:0.952855	validation_1-error:0.006054
# [385]	validation_0-auc:0.945835	validation_0-error:0.008326	validation_1-auc:0.952757	validation_1-error:0.006054
# [386]	validation_0-auc:0.946331	validation_0-error:0.008326	validation_1-auc:0.954616	validation_1-error:0.006054
# [387]	validation_0-auc:0.94649	validation_0-error:0.008336	validation_1-auc:0.954718	validation_1-error:0.006054
# [388]	validation_0-auc:0.946859	validation_0-error:0.008336	validation_1-auc:0.954908	validation_1-error:0.006054
# [389]	validation_0-auc:0.947251	validation_0-error:0.008341	validation_1-auc:0.955437	validation_1-error:0.006054
# [390]	validation_0-auc:0.947277	validation_0-error:0.008351	validation_1-auc:0.955552	validation_1-error:0.006054
# [391]	validation_0-auc:0.947703	validation_0-error:0.008346	validation_1-auc:0.953441	validation_1-error:0.006054
# [392]	validation_0-auc:0.947694	validation_0-error:0.008346	validation_1-auc:0.953391	validation_1-error:0.006054
# [393]	validation_0-auc:0.947858	validation_0-error:0.008341	validation_1-auc:0.953446	validation_1-error:0.006054
# [394]	validation_0-auc:0.948021	validation_0-error:0.008341	validation_1-auc:0.953361	validation_1-error:0.006054
# [395]	validation_0-auc:0.948023	validation_0-error:0.008336	validation_1-auc:0.953304	validation_1-error:0.006034
# [396]	validation_0-auc:0.94853	validation_0-error:0.008331	validation_1-auc:0.95379	validation_1-error:0.006054
# [397]	validation_0-auc:0.948657	validation_0-error:0.008326	validation_1-auc:0.953854	validation_1-error:0.006054
# [398]	validation_0-auc:0.949117	validation_0-error:0.008326	validation_1-auc:0.953977	validation_1-error:0.006014
# [399]	validation_0-auc:0.949172	validation_0-error:0.008322	validation_1-auc:0.954047	validation_1-error:0.006014
# [400]	validation_0-auc:0.949368	validation_0-error:0.008322	validation_1-auc:0.95406	validation_1-error:0.006014
# [401]	validation_0-auc:0.949666	validation_0-error:0.008317	validation_1-auc:0.954143	validation_1-error:0.006014
# [402]	validation_0-auc:0.950116	validation_0-error:0.008322	validation_1-auc:0.954774	validation_1-error:0.006014
# [403]	validation_0-auc:0.950101	validation_0-error:0.008317	validation_1-auc:0.954862	validation_1-error:0.006014
# [404]	validation_0-auc:0.950137	validation_0-error:0.008312	validation_1-auc:0.955088	validation_1-error:0.006014
# [405]	validation_0-auc:0.950875	validation_0-error:0.008302	validation_1-auc:0.955141	validation_1-error:0.006014
# [406]	validation_0-auc:0.950879	validation_0-error:0.008297	validation_1-auc:0.955123	validation_1-error:0.006014
# [407]	validation_0-auc:0.95111	validation_0-error:0.008287	validation_1-auc:0.952762	validation_1-error:0.005995
# [408]	validation_0-auc:0.951301	validation_0-error:0.008287	validation_1-auc:0.952507	validation_1-error:0.005975
# [409]	validation_0-auc:0.951291	validation_0-error:0.008292	validation_1-auc:0.952464	validation_1-error:0.005975
# [410]	validation_0-auc:0.951384	validation_0-error:0.008287	validation_1-auc:0.952439	validation_1-error:0.005975
# [411]	validation_0-auc:0.951324	validation_0-error:0.008277	validation_1-auc:0.952414	validation_1-error:0.005975
# [412]	validation_0-auc:0.951324	validation_0-error:0.008277	validation_1-auc:0.952401	validation_1-error:0.005995
# [413]	validation_0-auc:0.951544	validation_0-error:0.008277	validation_1-auc:0.953034	validation_1-error:0.005995
# [414]	validation_0-auc:0.951532	validation_0-error:0.008272	validation_1-auc:0.953002	validation_1-error:0.005995
# [415]	validation_0-auc:0.95216	validation_0-error:0.008267	validation_1-auc:0.953195	validation_1-error:0.005975
# [416]	validation_0-auc:0.95265	validation_0-error:0.008267	validation_1-auc:0.953229	validation_1-error:0.005975
# [417]	validation_0-auc:0.952814	validation_0-error:0.008267	validation_1-auc:0.953567	validation_1-error:0.005975
# [418]	validation_0-auc:0.953512	validation_0-error:0.008267	validation_1-auc:0.953993	validation_1-error:0.005975
# [419]	validation_0-auc:0.953544	validation_0-error:0.008267	validation_1-auc:0.953971	validation_1-error:0.005975
# [420]	validation_0-auc:0.953524	validation_0-error:0.008262	validation_1-auc:0.953941	validation_1-error:0.005975
# [421]	validation_0-auc:0.953761	validation_0-error:0.008257	validation_1-auc:0.954029	validation_1-error:0.005975
# [422]	validation_0-auc:0.953559	validation_0-error:0.008262	validation_1-auc:0.954117	validation_1-error:0.005975
# ...
# [863]	validation_0-auc:0.977041	validation_0-error:0.007434	validation_1-auc:0.97458	validation_1-error:0.00562
# [864]	validation_0-auc:0.977093	validation_0-error:0.007429	validation_1-auc:0.974613	validation_1-error:0.00562
# [865]	validation_0-auc:0.977139	validation_0-error:0.007429	validation_1-auc:0.974631	validation_1-error:0.00562
# [866]	validation_0-auc:0.977146	validation_0-error:0.007424	validation_1-auc:0.974635	validation_1-error:0.00562
# [867]	validation_0-auc:0.977168	validation_0-error:0.007424	validation_1-auc:0.974642	validation_1-error:0.00562
# [868]	validation_0-auc:0.977152	validation_0-error:0.007424	validation_1-auc:0.974644	validation_1-error:0.00562
# [869]	validation_0-auc:0.977157	validation_0-error:0.007424	validation_1-auc:0.974664	validation_1-error:0.00562
# [870]	validation_0-auc:0.977201	validation_0-error:0.007409	validation_1-auc:0.974675	validation_1-error:0.00562
# [871]	validation_0-auc:0.97724	validation_0-error:0.007414	validation_1-auc:0.974676	validation_1-error:0.00562
# [872]	validation_0-auc:0.977262	validation_0-error:0.007424	validation_1-auc:0.97467	validation_1-error:0.00562
# [873]	validation_0-auc:0.977282	validation_0-error:0.007414	validation_1-auc:0.974689	validation_1-error:0.0056
# [874]	validation_0-auc:0.977305	validation_0-error:0.007405	validation_1-auc:0.974671	validation_1-error:0.0056
# [875]	validation_0-auc:0.977307	validation_0-error:0.007405	validation_1-auc:0.974654	validation_1-error:0.0056
# [876]	validation_0-auc:0.977317	validation_0-error:0.007405	validation_1-auc:0.974683	validation_1-error:0.0056
# [877]	validation_0-auc:0.977332	validation_0-error:0.0074	validation_1-auc:0.974684	validation_1-error:0.005561
# [878]	validation_0-auc:0.977342	validation_0-error:0.00739	validation_1-auc:0.974687	validation_1-error:0.005561
# [879]	validation_0-auc:0.977343	validation_0-error:0.00739	validation_1-auc:0.974699	validation_1-error:0.005561
# [880]	validation_0-auc:0.977351	validation_0-error:0.00739	validation_1-auc:0.974704	validation_1-error:0.005561
# [881]	validation_0-auc:0.97735	validation_0-error:0.00739	validation_1-auc:0.974702	validation_1-error:0.005561
# [882]	validation_0-auc:0.977374	validation_0-error:0.00739	validation_1-auc:0.974706	validation_1-error:0.005561
# [883]	validation_0-auc:0.977367	validation_0-error:0.00739	validation_1-auc:0.97472	validation_1-error:0.005561
# [884]	validation_0-auc:0.977357	validation_0-error:0.007385	validation_1-auc:0.974743	validation_1-error:0.005561
# [885]	validation_0-auc:0.97737	validation_0-error:0.007385	validation_1-auc:0.974756	validation_1-error:0.005561
# [886]	validation_0-auc:0.977369	validation_0-error:0.00738	validation_1-auc:0.974756	validation_1-error:0.005561
# [887]	validation_0-auc:0.977389	validation_0-error:0.00738	validation_1-auc:0.974759	validation_1-error:0.005561
# [888]	validation_0-auc:0.977423	validation_0-error:0.00738	validation_1-auc:0.974761	validation_1-error:0.005561
# [889]	validation_0-auc:0.977481	validation_0-error:0.007375	validation_1-auc:0.974809	validation_1-error:0.005561
# [890]	validation_0-auc:0.977489	validation_0-error:0.007365	validation_1-auc:0.974879	validation_1-error:0.005561
# [891]	validation_0-auc:0.977495	validation_0-error:0.00736	validation_1-auc:0.974814	validation_1-error:0.005561
# [892]	validation_0-auc:0.977539	validation_0-error:0.007365	validation_1-auc:0.974835	validation_1-error:0.005561
# [893]	validation_0-auc:0.977552	validation_0-error:0.00736	validation_1-auc:0.974824	validation_1-error:0.005561
# [894]	validation_0-auc:0.977555	validation_0-error:0.007365	validation_1-auc:0.974891	validation_1-error:0.005561
# [895]	validation_0-auc:0.97756	validation_0-error:0.00736	validation_1-auc:0.974908	validation_1-error:0.005561
# [896]	validation_0-auc:0.977586	validation_0-error:0.007355	validation_1-auc:0.974915	validation_1-error:0.005561
# [897]	validation_0-auc:0.977614	validation_0-error:0.007345	validation_1-auc:0.974922	validation_1-error:0.005561
# [898]	validation_0-auc:0.977629	validation_0-error:0.00734	validation_1-auc:0.974946	validation_1-error:0.005561
# [899]	validation_0-auc:0.977653	validation_0-error:0.00734	validation_1-auc:0.97495	validation_1-error:0.005561
# [900]	validation_0-auc:0.977683	validation_0-error:0.007326	validation_1-auc:0.974961	validation_1-error:0.005541
# [901]	validation_0-auc:0.977743	validation_0-error:0.007326	validation_1-auc:0.975002	validation_1-error:0.005541
# [902]	validation_0-auc:0.977774	validation_0-error:0.007326	validation_1-auc:0.975042	validation_1-error:0.005541
# [903]	validation_0-auc:0.977795	validation_0-error:0.007326	validation_1-auc:0.9751	validation_1-error:0.005541
# [904]	validation_0-auc:0.977812	validation_0-error:0.007326	validation_1-auc:0.975097	validation_1-error:0.005541
# [905]	validation_0-auc:0.977816	validation_0-error:0.007326	validation_1-auc:0.975093	validation_1-error:0.005541
# [906]	validation_0-auc:0.977825	validation_0-error:0.007326	validation_1-auc:0.975097	validation_1-error:0.005541
# [907]	validation_0-auc:0.977851	validation_0-error:0.007326	validation_1-auc:0.975119	validation_1-error:0.005541
# [908]	validation_0-auc:0.977863	validation_0-error:0.007326	validation_1-auc:0.97513	validation_1-error:0.005541
# [909]	validation_0-auc:0.977879	validation_0-error:0.007321	validation_1-auc:0.975099	validation_1-error:0.005541
# [910]	validation_0-auc:0.977895	validation_0-error:0.007321	validation_1-auc:0.975105	validation_1-error:0.005541
# [911]	validation_0-auc:0.977904	validation_0-error:0.007316	validation_1-auc:0.975106	validation_1-error:0.005541
# [912]	validation_0-auc:0.977904	validation_0-error:0.007316	validation_1-auc:0.9751	validation_1-error:0.005541
# [913]	validation_0-auc:0.977905	validation_0-error:0.007306	validation_1-auc:0.9751	validation_1-error:0.005541
# [914]	validation_0-auc:0.977936	validation_0-error:0.007306	validation_1-auc:0.975175	validation_1-error:0.005541
# [915]	validation_0-auc:0.977955	validation_0-error:0.007306	validation_1-auc:0.975232	validation_1-error:0.005541
# [916]	validation_0-auc:0.97797	validation_0-error:0.007306	validation_1-auc:0.975273	validation_1-error:0.005541
# [917]	validation_0-auc:0.978012	validation_0-error:0.007301	validation_1-auc:0.975286	validation_1-error:0.005541
# [918]	validation_0-auc:0.978045	validation_0-error:0.007257	validation_1-auc:0.97535	validation_1-error:0.005541
# [919]	validation_0-auc:0.978072	validation_0-error:0.007257	validation_1-auc:0.975352	validation_1-error:0.005541
# [920]	validation_0-auc:0.978086	validation_0-error:0.007257	validation_1-auc:0.975329	validation_1-error:0.005541
# [921]	validation_0-auc:0.978107	validation_0-error:0.007257	validation_1-auc:0.975419	validation_1-error:0.005541
# [922]	validation_0-auc:0.978118	validation_0-error:0.007257	validation_1-auc:0.975437	validation_1-error:0.005541
# [923]	validation_0-auc:0.97814	validation_0-error:0.007257	validation_1-auc:0.975436	validation_1-error:0.005541
# [924]	validation_0-auc:0.978159	validation_0-error:0.007257	validation_1-auc:0.975455	validation_1-error:0.005541
# [925]	validation_0-auc:0.978191	validation_0-error:0.007257	validation_1-auc:0.975473	validation_1-error:0.005541
# [926]	validation_0-auc:0.978203	validation_0-error:0.007252	validation_1-auc:0.975477	validation_1-error:0.005541
# [927]	validation_0-auc:0.978202	validation_0-error:0.007252	validation_1-auc:0.97549	validation_1-error:0.005541
# [928]	validation_0-auc:0.978212	validation_0-error:0.007242	validation_1-auc:0.975496	validation_1-error:0.005541
# [929]	validation_0-auc:0.978217	validation_0-error:0.007242	validation_1-auc:0.975503	validation_1-error:0.005541
# [930]	validation_0-auc:0.978217	validation_0-error:0.007232	validation_1-auc:0.975499	validation_1-error:0.005541
# [931]	validation_0-auc:0.978238	validation_0-error:0.007227	validation_1-auc:0.975521	validation_1-error:0.005541
# [932]	validation_0-auc:0.978226	validation_0-error:0.007227	validation_1-auc:0.975525	validation_1-error:0.005541
# [933]	validation_0-auc:0.978227	validation_0-error:0.007227	validation_1-auc:0.975526	validation_1-error:0.005541
# [934]	validation_0-auc:0.978266	validation_0-error:0.007227	validation_1-auc:0.975558	validation_1-error:0.005541
# [935]	validation_0-auc:0.978274	validation_0-error:0.007227	validation_1-auc:0.97556	validation_1-error:0.005541
# [936]	validation_0-auc:0.978289	validation_0-error:0.007227	validation_1-auc:0.975602	validation_1-error:0.005541
# [937]	validation_0-auc:0.978386	validation_0-error:0.007227	validation_1-auc:0.975646	validation_1-error:0.005541
# [938]	validation_0-auc:0.978401	validation_0-error:0.007222	validation_1-auc:0.975676	validation_1-error:0.005541
# [939]	validation_0-auc:0.97841	validation_0-error:0.007222	validation_1-auc:0.97568	validation_1-error:0.005541
# [940]	validation_0-auc:0.978426	validation_0-error:0.007222	validation_1-auc:0.975686	validation_1-error:0.005541
# [941]	validation_0-auc:0.97846	validation_0-error:0.007222	validation_1-auc:0.975712	validation_1-error:0.005541
# [942]	validation_0-auc:0.978468	validation_0-error:0.007222	validation_1-auc:0.975724	validation_1-error:0.005541
# [943]	validation_0-auc:0.978502	validation_0-error:0.007217	validation_1-auc:0.975727	validation_1-error:0.005541
# [944]	validation_0-auc:0.978513	validation_0-error:0.007217	validation_1-auc:0.975736	validation_1-error:0.005541
# [945]	validation_0-auc:0.978531	validation_0-error:0.007222	validation_1-auc:0.975737	validation_1-error:0.005541
# [946]	validation_0-auc:0.978546	validation_0-error:0.007217	validation_1-auc:0.975798	validation_1-error:0.005541
# [947]	validation_0-auc:0.978564	validation_0-error:0.007222	validation_1-auc:0.975795	validation_1-error:0.005541
# [948]	validation_0-auc:0.978565	validation_0-error:0.007212	validation_1-auc:0.975804	validation_1-error:0.005541
# [949]	validation_0-auc:0.978589	validation_0-error:0.007212	validation_1-auc:0.975828	validation_1-error:0.005541
# [950]	validation_0-auc:0.978599	validation_0-error:0.007207	validation_1-auc:0.97583	validation_1-error:0.005541
# [951]	validation_0-auc:0.978599	validation_0-error:0.007207	validation_1-auc:0.975824	validation_1-error:0.005541
# [952]	validation_0-auc:0.97865	validation_0-error:0.007207	validation_1-auc:0.975833	validation_1-error:0.005541
# [953]	validation_0-auc:0.978665	validation_0-error:0.007207	validation_1-auc:0.97584	validation_1-error:0.005541
# [954]	validation_0-auc:0.978664	validation_0-error:0.007207	validation_1-auc:0.975838	validation_1-error:0.005541
# [955]	validation_0-auc:0.978686	validation_0-error:0.007207	validation_1-auc:0.975833	validation_1-error:0.005541
# [956]	validation_0-auc:0.978704	validation_0-error:0.007202	validation_1-auc:0.975839	validation_1-error:0.005541
# [957]	validation_0-auc:0.978711	validation_0-error:0.007202	validation_1-auc:0.975841	validation_1-error:0.005541
# [958]	validation_0-auc:0.978734	validation_0-error:0.007202	validation_1-auc:0.975849	validation_1-error:0.005541
# [959]	validation_0-auc:0.978761	validation_0-error:0.007207	validation_1-auc:0.975849	validation_1-error:0.005541
# [960]	validation_0-auc:0.978794	validation_0-error:0.007202	validation_1-auc:0.975855	validation_1-error:0.005541
# [961]	validation_0-auc:0.978785	validation_0-error:0.007198	validation_1-auc:0.975859	validation_1-error:0.005541
# [962]	validation_0-auc:0.978786	validation_0-error:0.007198	validation_1-auc:0.975861	validation_1-error:0.005541
# [963]	validation_0-auc:0.978794	validation_0-error:0.007193	validation_1-auc:0.975882	validation_1-error:0.005541
# [964]	validation_0-auc:0.978795	validation_0-error:0.007193	validation_1-auc:0.975883	validation_1-error:0.005561
# [965]	validation_0-auc:0.978834	validation_0-error:0.007188	validation_1-auc:0.975889	validation_1-error:0.005561
# [966]	validation_0-auc:0.97882	validation_0-error:0.007188	validation_1-auc:0.975889	validation_1-error:0.005561
# [967]	validation_0-auc:0.978841	validation_0-error:0.007193	validation_1-auc:0.975898	validation_1-error:0.005561
# [968]	validation_0-auc:0.978844	validation_0-error:0.007183	validation_1-auc:0.975898	validation_1-error:0.005561
# [969]	validation_0-auc:0.978841	validation_0-error:0.007183	validation_1-auc:0.975896	validation_1-error:0.005561
# [970]	validation_0-auc:0.978852	validation_0-error:0.007183	validation_1-auc:0.975901	validation_1-error:0.005561
# [971]	validation_0-auc:0.978869	validation_0-error:0.007183	validation_1-auc:0.975923	validation_1-error:0.005561
# [972]	validation_0-auc:0.978921	validation_0-error:0.007183	validation_1-auc:0.976004	validation_1-error:0.005561
# [973]	validation_0-auc:0.978988	validation_0-error:0.007183	validation_1-auc:0.976052	validation_1-error:0.005561
# [974]	validation_0-auc:0.97899	validation_0-error:0.007183	validation_1-auc:0.976054	validation_1-error:0.005561
# [975]	validation_0-auc:0.979014	validation_0-error:0.007183	validation_1-auc:0.976088	validation_1-error:0.005561
# [976]	validation_0-auc:0.979074	validation_0-error:0.007168	validation_1-auc:0.976065	validation_1-error:0.005561
# [977]	validation_0-auc:0.979073	validation_0-error:0.007173	validation_1-auc:0.976059	validation_1-error:0.005561
# [978]	validation_0-auc:0.979059	validation_0-error:0.007168	validation_1-auc:0.976076	validation_1-error:0.005561
# [979]	validation_0-auc:0.979088	validation_0-error:0.007178	validation_1-auc:0.976087	validation_1-error:0.005561
# [980]	validation_0-auc:0.979091	validation_0-error:0.007178	validation_1-auc:0.976089	validation_1-error:0.005561
# [981]	validation_0-auc:0.979092	validation_0-error:0.007178	validation_1-auc:0.976089	validation_1-error:0.005561
# [982]	validation_0-auc:0.979099	validation_0-error:0.007178	validation_1-auc:0.976112	validation_1-error:0.005561
# [983]	validation_0-auc:0.979112	validation_0-error:0.007163	validation_1-auc:0.976111	validation_1-error:0.005561
# [984]	validation_0-auc:0.979113	validation_0-error:0.007163	validation_1-auc:0.976123	validation_1-error:0.005561
# [985]	validation_0-auc:0.979103	validation_0-error:0.007163	validation_1-auc:0.976124	validation_1-error:0.005561
# [986]	validation_0-auc:0.979109	validation_0-error:0.007158	validation_1-auc:0.976123	validation_1-error:0.005561
# [987]	validation_0-auc:0.97911	validation_0-error:0.007153	validation_1-auc:0.976184	validation_1-error:0.005561
# [988]	validation_0-auc:0.979127	validation_0-error:0.007153	validation_1-auc:0.9762	validation_1-error:0.005561
# [989]	validation_0-auc:0.979149	validation_0-error:0.007153	validation_1-auc:0.976208	validation_1-error:0.005561
# [990]	validation_0-auc:0.979204	validation_0-error:0.007148	validation_1-auc:0.976208	validation_1-error:0.005561
# [991]	validation_0-auc:0.979207	validation_0-error:0.007138	validation_1-auc:0.976241	validation_1-error:0.005561
# [992]	validation_0-auc:0.979221	validation_0-error:0.007138	validation_1-auc:0.976246	validation_1-error:0.005561
# [993]	validation_0-auc:0.979235	validation_0-error:0.007138	validation_1-auc:0.976247	validation_1-error:0.005561
# [994]	validation_0-auc:0.97924	validation_0-error:0.007138	validation_1-auc:0.976238	validation_1-error:0.005561
# [995]	validation_0-auc:0.979239	validation_0-error:0.007143	validation_1-auc:0.976236	validation_1-error:0.005561
# [996]	validation_0-auc:0.979258	validation_0-error:0.007138	validation_1-auc:0.976262	validation_1-error:0.005561
# [997]	validation_0-auc:0.979267	validation_0-error:0.007138	validation_1-auc:0.976264	validation_1-error:0.005561
# [998]	validation_0-auc:0.979271	validation_0-error:0.007138	validation_1-auc:0.976261	validation_1-error:0.00558
# [999]	validation_0-auc:0.97929	validation_0-error:0.007133	validation_1-auc:0.976217	validation_1-error:0.00558
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.4, gamma=10,
#        learning_rate=0.01, max_delta_step=0, max_depth=4,
#        min_child_weight=1, missing=None, n_estimators=1000, n_jobs=1,
#        nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0.3, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, slient=False, subsample=0.8, verbosity=1)

# %%
plt.plot(model.evals_result_['validation_0']['auc'],label='train')
plt.plot(model.evals_result_['validation_1']['auc'],label='test')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Since we have imbalanced dataset, we evaluate model performance based on auc-roc not error

# %% [markdown]
# #### after find best number of tree, start to fine tune for tree structure params

# %%
params = {'learning_rate': 0.1, 'n_estimators': 600, 
         'max_depth': [3,5,7,9], 'colsample_bytree':0.4,
         'objective': 'binary:logistic', 
         }

# %% [markdown]
# #### after finding best values for trees, now start to fine tune to find learning-rate

# %% [markdown]
# ### Adding unique sites# for each session

# %%
sites = ['site%d' %i for i in range(1,11)]
times = ['time%d' %i for i in range(1,11)]
train_df = pd.read_csv('train_sessions.csv',index_col='session_id', parse_dates=times)
test_df = pd.read_csv('test_sessions.csv', index_col='session_id', parse_dates=times)

train_df = train_df.sort_values(by='time1')

# clean data 
train_df[sites] = train_df[sites].fillna(0).astype('int')
test_df[sites] = test_df[sites].fillna(0).astype('int')

# %%
# Let's see what is most freq website of Alice use
Alice_df = train_df[train_df['target']==1]
other_df = train_df[train_df['target']==0]
top_sites_alice = pd.Series(Alice_df[sites].values.flatten()).value_counts().drop(labels=[0]).sort_values(ascending=False).head(20)
top_sites_other = pd.Series(other_df[sites].values.flatten()).value_counts().drop(labels=[0]).sort_values(ascending=False).head(20)

def uniq_count(x):
    uniq_array = np.unique(x)
    uniq_ct = len(uniq_array)
    if 0 in uniq_array:
        uniq_ct-=1
    return uniq_ct


train_uniq_session = train_df[sites].apply(uniq_count, axis=1).values.reshape(-1,1) # without NaN sites
test_uniq_session = test_df[sites].apply(uniq_count, axis=1).values.reshape(-1,1)
train_uniq_session = scaler.fit_transform(train_uniq_session)
test_uniq_session = scaler.transform(test_uniq_session)

new_train_adduniq = hstack([new_train_addYMD, train_uniq_session])
new_test_adduniq = hstack([new_test_addYMD, test_uniq_session])
# Out:
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
new_features2+=['unique']

# %%
logit_new = LogisticRegression(C=1.0, random_state=17, n_jobs=-1, solver='liblinear', max_iter=100)
cv_add_YMD_feat = train_and_predict(logit_new, new_train_adduniq, y_train, new_test_adduniq, site_features=tfv.get_feature_names(), new_feature_names=new_features2,
                     cv=time_split, scoring='roc_auc', top_n_features=30, submission_file='submission.csv')
# Out:
# CV ROC Score->[0.77019893 0.81615594 0.94529484 0.963903   0.91676763 0.95975906
#  mean: 0.917981993794205, std: 0.06511581813691804
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.11%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.160
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.007
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.993
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.969
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.29%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.707
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.01%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.437
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.11%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.400
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.audienceinsights.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.13%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.392
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.021
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.39%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.929
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.753
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         r4---sn-gxo5uxg-jqbe.googlevideo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.737
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         i1.ytimg.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.659
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.616
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.586
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.514
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.67%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.480
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.438
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.370
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.27%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.271
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         reviewer.lavoixdunord.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.245
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.video.tt
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.224
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub128.mail.live.co

# %% [markdown]
# ### Adding site# each session have based on alice_top20_unique (different with other_top20_unique)

# %%
alice_uniq_top = set(alice_top20) - set(other_top20)

# %%
# add top 20 alice website 
alice_top20 = list(top_sites_alice.index)
alice_top20.sort()
other_top20 = list(top_sites_other.index)
other_top20.sort()

def have_top20_alice_sites(x, top20_sites):
    uniq_session = set(np.unique(x))
    have_top20_cnt = list(set(top20_sites) & uniq_session)
    return len(have_top20_cnt)

train_have_top20 = train_df[sites].apply(have_top20_alice_sites, top20_sites=alice_uniq_top, axis=1).values.reshape(-1,1)
test_have_top20 = test_df[sites].apply(have_top20_alice_sites, top20_sites=alice_uniq_top, axis=1).values.reshape(-1,1)
# train_have_top20 = scaler.fit_transform(train_have_top20)
# test_have_top20 = scaler.transform(test_have_top20)

new_train_addtop20 = hstack([new_train_adduniq, train_have_top20])
new_test_addtop20 = hstack([new_test_adduniq, test_have_top20])

# %%
new_features2+=['Have_top20_alice']

# %%
logit_new = LogisticRegression(C=4.6415888336127775, random_state=17, n_jobs=-1, solver='liblinear', max_iter=100, penalty='l2')
cv_add_YMD_feat = train_and_predict(logit_new, new_train_addtop20, y_train, new_test_addtop20, site_features=tfv.get_feature_names(), new_feature_names=new_features2,
                     cv=time_split, scoring='roc_auc', top_n_features=30, submission_file='submission.csv')
# Out:
# CV ROC Score->[0.78752551 0.80324791 0.95083693 0.97234163 0.91968064 0.95648644
#  mean: 0.921396302070578, std: 0.0645906936074649
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +11.721
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +11.364
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.81%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.909
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         tru.am
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.105
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.78%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.487
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.04%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.307
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.288
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.195
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.017
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mcetv.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.889
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.springboardplatform.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.817
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.751
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.733
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.radio-canada.ca
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.725
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.kelbillet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.02%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.633
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.video.tt
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.630
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.12%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.569
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         media-1.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.526
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.clermont-filmfest.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.30%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.446
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.rhonealpesjob.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.426
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.413
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.videostep.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.39%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.391
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.tete-en-lair.com
#     </td>

# %% [markdown]
# ## grid search

# %%
logit = LogisticRegression(random_state=17, solver='liblinear')
params = {
    'penalty':['l1','l2'],
    'C': np.logspace(-2,2,10)
}

grid = GridSearchCV(estimator=logit, param_grid=params, scoring='roc_auc', cv=time_split, verbose=1, n_jobs=-1)
grid.fit(new_train_addtop20, y_train)
grid.best_estimator_, grid.best_score_, grid.best_params_
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed: 43.2min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed: 48.6min finished
# (LogisticRegression(C=4.6415888336127775, class_weight=None, dual=False,
#            fit_intercept=True, intercept_scaling=1, max_iter=100,
#            multi_class='warn', n_jobs=None, penalty='l2', random_state=17,
#            solver='liblinear', tol=0.0001, verbose=0, warm_start=False),
#  0.9218592784620138,
#  {'C': 4.6415888336127775, 'penalty': 'l2'})

# %% [markdown]
# ## Xgboost model

# %%
xgb = XGBClassifier(slient=False,
                     scale_pos_weight=1,
                     learning_rate=0.01,
                     colsample_bytree=0.4,
                     subsample=0.8,
                     objective='binary:logistic',
                     n_estimators=1000,
                     reg_alpha=0.3,
                     max_depth=4,
                     gamma=10)

# %%
xgb.fit(new_train_addYMD, y_train,eval_metric='auc')
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.4, gamma=10,
#        learning_rate=0.01, max_delta_step=0, max_depth=4,
#        min_child_weight=1, missing=None, n_estimators=1000, n_jobs=1,
#        nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0.3, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, slient=False, subsample=0.8, verbosity=1)

# %%
test_pred = xgb.predict_proba(new_test_addYMD)[:,-1]
write_to_submission_file(test_pred, out_file='submission_xgb.csv')

# %%
test_pred
# Out:
# array([0.00028554, 0.00016251, 0.00201537, ..., 0.00023464, 0.00025884,
#        0.00026675], dtype=float32)

# %% [markdown]
# ## Add YMD as Categorical Feature
# ### 93.8%

# %%
train_weekday_feat = train_times['time1'].apply(lambda ts: ts.weekday()).values.reshape(-1,1)
train_yearmonth_feat = (train_times['time1'].apply(lambda ts: ts.year*100+ts.month)/1e5).values.reshape(-1,1)
train_month_feat = train_times['time1'].apply(lambda ts: ts.month).values.reshape(-1,1)

test_weekday_feat = test_times['time1'].apply(lambda ts: ts.weekday()).values.reshape(-1,1)
test_yearmonth_feat = (test_times['time1'].apply(lambda ts: ts.year*100+ts.month)/1e5).values.reshape(-1,1)
test_month_feat = test_times['time1'].apply(lambda ts: ts.month).values.reshape(-1,1)

# %%
weekday_train = train_times['time1'].apply(lambda ts: ts.weekday()).values.astype(str)
weekday_test = test_times['time1'].apply(lambda ts: ts.weekday()).values.astype(str)

from sklearn.preprocessing import OneHotEncoder
one_hot = OneHotEncoder()
train_week = one_hot.fit_transform(weekday_train.reshape(-1,1))
test_week = one_hot.transform(weekday_test.reshape(-1,1))
# Out:
# C:\Users\900309\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
month_map = {'1': 'Jan.', '2': 'Feb.', '3': 'Mar.', '4': 'Apr', '5': 'May', '6': 'Jun', '7': 'Jul', '8': 'Aug',
            '9': 'Sep', '10': 'Oct', '11': 'Nov', '12': 'Dec'}
month_train = train_times['time1'].apply(lambda ts: month_map[str(ts.month)]).values.reshape(-1,1)
month_test = test_times['time1'].apply(lambda ts: month_map[str(ts.month)]).values.reshape(-1,1)
train_month = one_hot.fit_transform(month_train)
test_month = one_hot.transform(month_test)

# %%
new_train_wYMD_cate = hstack([new_train_wdur,train_week, train_yearmonth_feat ,train_month]) 
new_test_wYMD_cate = hstack([new_test_wdur, test_week, test_yearmonth_feat ,test_month])

# %%
new_features3 = new_features2[:5].copy()
new_features3+=['%d' %i for i in range(1,8)]
new_features3+=['yearmonth']
new_features3+=[month_map[i] for i in month_map]

# %%
logit_higher_iter = LogisticRegression(random_state=17, C=4, max_iter=100, solver='lbfgs',n_jobs=-1)
cv_add_YMD_cate_feat = train_and_predict(logit_higher_iter, new_train_wYMD_cate, y_train, new_test_wYMD_cate, site_features=tfv.get_feature_names(), new_feature_names=new_features3,
                     cv=time_split, scoring='roc_auc', top_n_features=30, submission_file='submission.csv')
# Out:
# CV ROC Score->[0.85480942 0.90263939 0.86556446 0.98159654 0.85981031 0.9729935
#  mean: 0.9147159707392566, std: 0.05272820462163403
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +10.304
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.express.co.uk
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.74%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +10.013
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cid-ed6c3e6a5c6608a4.users.storage.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.286
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vk.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.69%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.213
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.banque-chalus.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.01%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.997
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fr.glee.wikia.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.708
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.video.tt
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.76%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.501
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         api.bing.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.401
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         browser-update.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.94%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.388
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.clermont-filmfest.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.230
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         tru.am
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.192
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jeux.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.120
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.tete-en-lair.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.104
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.info-jeunes.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.983
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         glee.hypnoweb.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.901
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         video.tt
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.820
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         seriestreaming.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.06%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.675
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         youwatch.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.09%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.652
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         static.weezbe.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.27%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.540
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dub119.mail.live.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.30%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.521
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.melty.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.511
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         s.radio-canada.ca
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.351
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.regarder-film-gratuit.com
#     </td>
#
# </tr>

# %%
pd.DataFrame({'feat_name': new_features3, 'coef': logit_higher_iter.coef_[0][-len(new_features3):]})
# Out:
#         feat_name      coef
# 0         morning -1.545675
# 1             day  2.181304
# 2         evening -1.733231
# 3           night  0.000000
# 4   duration time -0.301149
# 5               1  1.727957
# 6               2  0.793391
# 7               3 -2.016471
# 8               4 -0.781472
# 9               5  0.349274
# 10              6  0.915358
# 11              7 -2.085638
# 12      yearmonth -2.204575
# 13           Jan.  0.247545
# 14           Feb. -0.876355
# 15           Mar.  0.204357
# 16            Apr  0.049686
# 17            May -1.264388
# 18            Jun -0.046690
# 19            Jul -0.605269
# 20            Aug -0.251649
# 21            Sep -0.783999
# 22            Oct  0.692218
# 23            Nov -2.170986
# 24            Dec  3.707928
